# %% [markdown]
# # Implementing and Comparing Activations functions

# %% [markdown]
# ## Abstract
#
# Neural network activation functions are a crucial component of deep learning. Activation functions determine the output of a deep learning model, its accuracy, and also the computational efficiency of training a model—which can make or break a large scale neural network. Activation functions also have a major effect on the neural network’s ability to converge and the convergence speed.<br />
# <br />
# In this project, I have implemented various Activation functions like `sigmoid, tanH, ReLU, Leaky ReLU, Parametric ReLU, and Swish` etc. Compared their outputs, accuracy, loss along with the time taken by each function to converge. <br />
# <br />
# I have created `Convolutional Neural Network(CNN)` model that is used across all Activation functions to maintain consistency and validness. The CNN model is implemented using `TensorFlow` and the data is acquired from `Intel Image Classification` competition which held on Analyticsvidya.com. <br />
# <br />
# Aim of this project is to elaborate the importance of different activation functions rather than getting accurate classification or get more and more accuracy

# %% [markdown]
# ### Import the required libraries

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import re
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)
config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math

#Keras libraries
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import *
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools 
import matplotlib.pyplot as plt
import seaborn as sn                        
from sklearn.utils import shuffle
import os
import cv2

from IPython.display import display 
from PIL import Image
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### TensorFlow Version working with

# %%
tf.__version__
# Out:
# '1.14.0'

# %% [markdown]
# #### Here's our 6 categories that we have to classify.

# %%
# class_names = ['mountain', 'street', 'glacier', 'buildings', 'sea', 'forest']
# class_names_label = {'mountain': 0,
#                     'street' : 1,
#                     'glacier' : 2,
#                     'buildings' : 3,
#                     'sea' : 4,
#                     'forest' : 5
#                     }
# nb_classes = 6
class_names = ['buildings', 'forest']
class_names_label = {'buildings': 0,
                    'forest' : 1
                    }
nb_classes = 6

# %% [markdown]
# #### Load the data

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 10,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['seg_train//seg_train', 'seg_test//seg_test']
    size = (150,150)
    output = []
    for dataset in datasets:
        #directory = "C://Users//kaila//OneDrive//Desktop//ADS//Project - Implementing Activations functions & Swish//Dataset//" + dataset
        directory = "Dataset//" + dataset
        images = []
        labels = []
        for folder in os.listdir(directory):
            curr_label = class_names_label[folder]
            for file in os.listdir(directory + "/" + folder):
                img_path = directory + "/" + folder + "/" + file
                curr_img = cv2.imread(img_path)
                curr_img = cv2.resize(curr_img, size)
                images.append(curr_img)
                labels.append(curr_label)
        images, labels = shuffle(images, labels)    
        images = np.array(images, dtype = 'float32') 
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %% [markdown]
# `load_data functon:`
# - It load Train and Test image data
# - Read the images using openCV
# - Since in competion its asked for image to be of size 150*150 so I am rescalling it, it will help in faster convergence.
# - Append images and labels to their respective list
# - shuffling the data
# - Converting images and labels to Numpy array so it will be easier to normalize the later

# %% [markdown]
# ### Loading Training and Evaluation data

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()

# %%
train_data = train_images
train_labels = train_labels.astype(np.int32)  # not required

eval_data = test_images
eval_labels = test_labels.astype(np.int32)  # not required

# %%
print ("Number of training examples: " + str(train_labels.shape[0]))
print ("Number of testing examples: " + str(test_labels.shape[0]))
print ("Each image is of size: " + str(train_images.shape[1:]))
# Out:
# Number of training examples: 4462
# Number of testing examples: 911
# Each image is of size: (150, 150, 3)

# %% [markdown]
# - Our image dataset contain 14034 Training and 3000 test images 150*150 size of 3 channel (i.e colored RGB images)

# %% [markdown]
# #### Lets plot a pie chart of image distribution of 6 type

# %%
# Plot a pie chart
sizes = np.bincount(train_labels)
# explode = (0, 0, 0, 0, 0, 0)  
explode = (0, 0)  
plt.pie(sizes, explode=explode, labels=class_names,
autopct='%1.2f%%', shadow=True, startangle=150)
plt.axis('equal')
plt.title('Proportion of each observed category')

plt.show()

# %% [markdown]
# #### Its good practice to Normalize pixel values to be between 0 and 1

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
print('x_images.shape =', train_images.shape)
print('x_images.min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(train_images.min(),
                        train_images.mean(), train_images.std(), train_images.max()))
print('')
print('y_images.shape =', test_images.shape)
print('y_images.min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(test_images.min(),
                        test_images.mean(), test_images.std(), test_images.max()))
# Out:
# x_images.shape = (4462, 150, 150, 3)
# x_images.min/mean/std/max = 0.00/0.38/0.28/1.00
#
# y_images.shape = (911, 150, 150, 3)
# y_images.min/mean/std/max = 0.00/0.38/0.28/1.00

# %% [markdown]
# #### Plot some random images from our dataset

# %%
fig = plt.figure(figsize=(20,10))
fig.suptitle("Some examples of images of the dataset", fontsize=16)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ### Create global variable to set Activation function

# %%
act_func_global = tf.nn.relu       #Here I set it default to relu so that our variable became of that type
print(act_func_global)
is_Swish = False
print('is a Swish function: ',is_Swish)
is_SwishBeta = False
print('is a Swish Beta function: ',is_SwishBeta)
is_First = True
print('is a first function: ',is_Swish)
b_size=30
print('batch size: ',b_size)
epochs=10
print('batch size: ',b_size)
# Out:
# <function relu at 0x000002161CEE3A68>
# is a Swish function:  False
# is a Swish Beta function:  False
# is a first function:  False
# batch size:  30
# batch size:  30

# %% [markdown]
# ### Create CNN Model for different Activation Functions

# %%
def cnn_model_fn(features, labels, mode):
    
    """Model function for CNN."""
    # act_func=tf.nn.relu
    
    print('act_func_global: ',act_func_global)
    
    # Input Layer
    input_layer = tf.reshape(features["x"], [-1, 150, 150, 3])       #All of our images are of size 150*150
    if is_First == True:
        print('input layer shape: ',tf.shape(input_layer))
        print(input_layer.get_shape())
    
    if is_Swish == True:
        swish_1(input_layer)
    if is_SwishBeta == True:
        swish_beta(input_layer)
    # Convolutional Layer #1
    conv1 = tf.layers.conv2d(
      inputs=input_layer,
      filters=32,
      kernel_size=[3, 3],
      padding="same",
      activation=act_func_global)
    if is_First == True:
        print('con1 shape: ',tf.shape(conv1))
        print(conv1.get_shape())

    # Pooling Layer #1
    pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)
    if is_First == True:
        print('pool1 Layer shape: ',tf.shape(pool1))
        print(pool1.get_shape())
    
    #local_response_normalization
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.01 / 3.0, beta=0.75, name='norm1')
    if is_First == True:
        print('local_response_normalization shape: ',tf.shape(norm1))
        print(norm1.get_shape())
    
    if is_Swish == True:
        swish_1(norm1)
    if is_SwishBeta == True:
        swish_beta(norm1)
    # Convolutional Layer #2 and Pooling Layer #2
    conv2 = tf.layers.conv2d(
      inputs=norm1,
      filters=64,
      kernel_size=[3, 3],
      padding="same",
      activation=act_func_global)
    if is_First == True:
        print('con2 Layer shape: ',tf.shape(conv2))
        print(conv2.get_shape())
    
    pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)
    if is_First == True:
        print('pool2 Layer shape: ',tf.shape(pool2))
        print(pool2.get_shape())
    
    
    # We'll flatten our feature map (pool2) to shape [batch_size, features], so that our tensor has only two dimensions
    # pool2_flat = tf.reshape(pool2, [-1, 37 * 37 * 64])
    pool2_flat = tf.reshape(pool2, [-1, pool2.get_shape()[1] * pool2.get_shape()[2] * 64])
    if is_First == True:
        print('pool2_flat shape: ',tf.shape(pool2_flat))
        print(pool2_flat.get_shape())
    
    if is_Swish == True:
        swish_1(pool2_flat)
        
    if is_SwishBeta == True:
        swish_beta(pool2_flat)
    # Dense Layer
    dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=act_func_global)
    if is_First == True:
        print('dense Layer shape: ',tf.shape(dense))
        print(dense.get_shape())
    
    # Drop the 10% of the input
#     dropout = tf.layers.dropout(inputs=dense, rate=0.1, training=mode == tf.estimator.ModeKeys.TRAIN)
#     print('dropout Regularizatin shape: ',tf.shape(dropout))
#     print(dropout.get_shape())
    
        
    # Logits Layer
    logits = tf.layers.dense(inputs=dense, units=2) # Here we have 6 Classes
    if is_First == True:
        print('logits Layer shape: ',tf.shape(logits))
        print(logits.get_shape())
    
    predictions = {
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1),
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
    }

    if mode == tf.estimator.ModeKeys.PREDICT:
        print('Mode: ',mode)
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    # Calculate Loss (for both TRAIN and EVAL modes)
    print('Train Loss: ')
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)

    # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
        print('Mode: ',mode)
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
        # print("Optimizer: ",optimizer)
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
        # print('train_op: ',train_op)
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    print(' ')
    # Add evaluation metrics (for EVAL mode)
    eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predictions["classes"])
    }
    
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %% [markdown]
# <img src="CNN-Model.jpeg" width="1000" align="Left" >

# %% [markdown]
# #### Model Explanation:
# <span style="color:#096694" >
#
# - A `cnn_model_fn` function takes features(i.e Input Image data), labels(i.e Image categorie), and mode(i.e Train, Test, Validate) as a input
# - I have created global variable `act_func_global` of type `tf.nn` and can be set each time for diffrent activation function
# - 1st layer is `input layer` which takes features and dimention as imput and outputs `4D-tensor` of size `(batch_size, 150 X 150 X 3)`
# - 2nd layer is Convolutional Layer- `conv1`, with `32` filters and kernel size `3X3` which ouputs 4D-tensor of size `(batch_size, 150 X 150 X 32)` and there is no dimension reduction since we are using `same` padding
# - 3rd layer is Pooling Layer- `pool1`, with pool size `2X2`, strides = `2` and which ouputs 4D-tensor of size `(batch_size, 75 X 75 X 32)` and there is dimension reduction
# - 4th layer is Normalization- `local_response_normalization`, Here the 4-D `input` tensor is treated as a 3-D array of 1-D vectors (along the last dimension), and each vector is normalized independently.  Within a given vector, each component is divided by the weighted, squared sum of inputs within `depth_radius`
# - 5th layer is Convolutional Layer- `conv2`, with `64` filters and kernel size `3X3` which ouputs 4D-tensor of size `(batch_size, 75 X 75 X 64)` and there is no dimension reduction since we are using `same` padding
# - 6th layer is Pooling Layer- `pool2`, with pool size `2X2`, strides = `2` and which ouputs 4D-tensor of size `(batch_size, 37 X 37 X 64)` and there is dimension reduction
# - 7th layer is FLatten Layer- `pool2_flat`, which flatten our feature map (pool2) to shape [batch_size, features], so that our tensor has only two dimensions. The `2-D tensor` size became (batch_size, 87616)
# - 8th layer is Dense/Fully connected layer- `dense`, which implements the operation:`outputs = activation(inputs * kernel + bias)`. It outputs the tensor of size (batch_size, 1024)
# - 9th layer is Logits/Dense Layer- `logits`, Here we reduce the size of neurons to output as 6, since we have `6 classes/labels to predict`. The output size of this layer is (batch_size,6)
# - For predictions I am using `softmax` function on outputs from `tf.nn.softmax`.
# - To Calculate Loss (for both TRAIN and EVAL modes) I am using `sparse_softmax_cross_entropy` (i.e Cross-entropy loss). Here, `weights` acts as a coefficient for the loss. If a scalar is provided, then the loss is simply scaled by the given value. If weights is a tensor of shape `[batch_size]`, then the loss weights apply to each corresponding sample.
# - To `optimise` the predictions i am usning `GradientDescentOptimizer` with `learn rate 0.01` that can be tweak futher for better accuracy
# <br />
# <br />
# - In the reshape() operation above, the -1 signifies that the batch_size dimension will be dynamically calculated based on the number of examples in our input data.

# %% [markdown]
# ### Create the Estimator
# Estimator (a TensorFlow class for performing high-level model training, evaluation, and inference) for our model.

# %%
# Create the Estimator
actfn_classifier = tf.estimator.Estimator(model_fn=cnn_model_fn, 
            model_dir="Estimator//actfn_convnet_model")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# I0814 21:25:33.941957  1940 estimator.py:1790] Using default config.
# I0814 21:25:33.943951  1940 estimator.py:209] Using config: {'_model_dir': 'Estimator//actfn_convnet_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000216D5787B88>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# - The model_fn argument specifies the model function to use for training, evaluation, and prediction; we pass it the actfn_classifier we created
# - The model_dir argument specifies the directory where model data (checkpoints) will be saved

# %% [markdown]
# ### Set Up a Logging Hook

# %%
# Set up logging for predictions
tensors_to_log = {"probabilities": "softmax_tensor"}

logging_hook = tf.train.LoggingTensorHook(
    tensors=tensors_to_log, every_n_iter=100)

# %% [markdown]
# - Since CNNs can take a while to train, let's set up some logging so we can track progress during training
# - We set every_n_iter=50, which specifies that probabilities should be logged after every 50 steps of training.

# %% [markdown]
# ## <span style="color:#b80f0f"> Sigmoid Function

# %% [markdown]
# <img src="Presentation/sigmoid.png" width="400" height="200" align="center" >

# %% [markdown]
# `Smooth gradient`, preventing “jumps” in output values.<br />
# `Output values bound` between 0 and 1, normalizing the output of each neuron.<br />
# `Clear predictions`- For X above 2 or below -2, tends to bring the Y value (the prediction) to the edge of the curve, very close to 1 or 0. This enables clear predictions.

# %% [markdown]
# #### Set a activation function

# %%
act_func_global=tf.nn.sigmoid
print(act_func_global)
is_Swish = False
is_First = True
# Out:
# <function sigmoid at 0x0000026B9862B798>

# %% [markdown]
# ### Train the Model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=epochs,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# W0814 19:28:26.444875 15764 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0814 19:28:26.456842 15764 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0814 19:28:26.459835 15764 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# I0814 19:28:26.468812 15764 estimator.py:1145] Calling model_fn.
# W0814 19:28:26.473797 15764 deprecation.py:323] From <ipython-input-13-e37c3dcb5a46>:24: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0814 19:28:26.476789 15764 deprecation.py:506] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# act_func_global:  <function sigmoid at 0x0000026B9862B798>
# input layer shape:  Tensor("Shape:0", shape=(4,), dtype=int32)
# (100, 150, 150, 3)
# con1 shape:
# W0814 19:28:26.657786 15764 deprecation.py:323] From <ipython-input-13-e37c3dcb5a46>:30: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# W0814 19:28:26.778545 15764 deprecation.py:323] From <ipython-input-13-e37c3dcb5a46>:75: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
#  Tensor("Shape_1:0", shape=(4,), dtype=int32)
# (100, 150, 150, 32)
# pool1 Layer shape:  Tensor("Shape_2:0", shape=(4,), dtype=int32)
# (100, 75, 75, 32)
# local_response_normalization shape:  Tensor("Shape_3:0", shape=(4,), dtype=int32)
# (100, 75, 75, 32)
# con2 Layer shape:  Tensor("Shape_4:0", shape=(4,), dtype=int32)
# (100, 75, 75, 64)
# pool2 Layer shape:  Tensor("Shape_5:0", shape=(4,), dtype=int32)
# (100, 37, 37, 64)
# pool2_flat shape:  Tensor("Shape_6:0", shape=(2,), dtype=int32)
# (100, 87616)
# W0814 19:28:27.012433 15764 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# I0814 19:28:27.102170 15764 estimator.py:1147] Done calling model_fn.
# I0814 19:28:27.104165 15764 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# dense Layer shape:  Tensor("Shape_7:0", shape=(2,), dtype=int32)
# (100, 1024)
# logits Layer shape:  Tensor("Shape_8:0", shape=(2,), dtype=int32)
# (100, 2)
# Train Loss:
# Mode:  train
# I0814 19:28:27.419707 15764 monitored_session.py:240] Graph was finalized.
# W0814 19:28:28.202069 15764 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# I0814 19:28:28.207724 15764 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1
# W0814 19:28:29.103418 15764 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1066: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# I0814 19:28:29.130426 15764 session_manager.py:500] Running local_init_op.
# I0814 19:28:29.135356 15764 session_manager.py:502] Done running local_init_op.
# W0814 19:28:29.145329 15764 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\monitored_session.py:875: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# I0814 19:28:29.771705 15764 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:28:35.906884 15764 basic_session_run_hooks.py:262] probabilities = [[0.00182912 0.99817085]
#  [0.00201355 0.99798644]
#  [0.00284113 0.9971589 ]
#  [0.00225977 0.99774027]
#  [0.00388673 0.9961133 ]
#  [0.00313198 0.9968681 ]
#  [0.00409083 0.9959092 ]
#  [0.00212541 0.9978746 ]
#  [0.0022717  0.9977283 ]
#  [0.00208462 0.9979153 ]
#  [0.00220836 0.99779165]
#  [0.0031621  0.99683785]
#  [0.00266062 0.9973394 ]
#  [0.00239808 0.9976019 ]
#  [0.00361679 0.9963832 ]
#  [0.00339563 0.9966043 ]
#  [0.00238051 0.99761945]
#  [0.00339955 0.99660045]
#  [0.00211119 0.99788886]
#  [0.00197009 0.9980299 ]
#  [0.00163447 0.9983656 ]
#  [0.0027036  0.9972964 ]
#  [0.00261755 0.99738246]
#  [0.0030163  0.9969837 ]
#  [0.00309992 0.9969001 ]
#  [0.00165708 0.9983429 ]
#  [0.00225202 0.99774796]
#  [0.00334241 0.9966576 ]
#  [0.00282539 0.9971746 ]
#  [0.00247489 0.99752516]
#  [0.00210818 0.99789184]
#  [0.00403108 0.99596894]
#  [0.00309157 0.9969085 ]
#  [0.00166963 0.9983304 ]
#  [0.00204834 0.9979517 ]
#  [0.00244799 0.997552  ]
#  [0.00193397 0.998066  ]
#  [0.0023259  0.99767405]
#  [0.00325452 0.99674547]
#  [0.00230261 0.9976974 ]
#  [0.0023132  0.99768674]
#  [0.00373896 0.99626106]
#  [0.00298116 0.9970188 ]
#  [0.00336247 0.99663746]
#  [0.00193032 0.9980697 ]
#  [0.00222033 0.99777967]
#  [0.00208225 0.9979177 ]
#  [0.00248765 0.99751234]
#  [0.00334727 0.9966528 ]
#  [0.00237189 0.99762815]
#  [0.00352431 0.99647564]
#  [0.00175829 0.99824166]
#  [0.00185313 0.9981469 ]
#  [0.00174551 0.9982545 ]
#  [0.00199396 0.99800605]
#  [0.00215549 0.99784446]
#  [0.00186182 0.9981382 ]
#  [0.0021615  0.99783856]
#  [0.00195952 0.9980405 ]
#  [0.00177557 0.99822444]
#  [0.002352   0.99764794]
#  [0.00166753 0.99833244]
#  [0.00208143 0.99791855]
#  [0.00320385 0.9967962 ]
#  [0.00196265 0.9980374 ]
#  [0.00374035 0.9962597 ]
#  [0.00176394 0.99823606]
#  [0.00347352 0.9965264 ]
#  [0.00299263 0.9970074 ]
#  [0.00279667 0.99720335]
#  [0.00307653 0.9969235 ]
#  [0.0024464  0.99755365]
#  [0.0032505  0.9967495 ]
#  [0.00221168 0.9977883 ]
#  [0.00204427 0.9979557 ]
#  [0.00207515 0.9979248 ]
#  [0.00180173 0.99819833]
#  [0.00202675 0.99797326]
#  [0.00349393 0.9965061 ]
#  [0.00182232 0.99817765]
#  [0.00305787 0.9969421 ]
#  [0.00255948 0.99744046]
#  [0.00173399 0.99826604]
#  [0.00213317 0.9978668 ]
#  [0.00192572 0.9980743 ]
#  [0.00187438 0.9981256 ]
#  [0.00188389 0.99811614]
#  [0.00277123 0.9972288 ]
#  [0.0037899  0.9962101 ]
#  [0.00353767 0.9964624 ]
#  [0.00353733 0.99646264]
#  [0.00226392 0.9977361 ]
#  [0.00206932 0.99793065]
#  [0.00253452 0.9974655 ]
#  [0.00219545 0.9978046 ]
#  [0.00159986 0.99840015]
#  [0.00266175 0.99733824]
#  [0.00334697 0.996653  ]
#  [0.0021227  0.99787736]
#  [0.00175844 0.99824154]]
# I0814 19:28:35.909876 15764 basic_session_run_hooks.py:262] loss = 2.4936683, step = 1
# I0814 19:28:35.910874 15764 basic_session_run_hooks.py:606] Saving checkpoints for 2 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:28:38.162418 15764 estimator.py:368] Loss for final step: 2.4936683.

# %% [markdown]
# #### Now—without logging each step—set steps=1000 to train the model longer, but in a reasonable time to run this example. Training CNNs is computationally intensive. To increase the accuracy of your model, increase the number of steps passed to train(), like 20,000 steps.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0814 19:29:42.798281 15764 estimator.py:1145] Calling model_fn.
# I0814 19:29:42.968857 15764 estimator.py:1147] Done calling model_fn.
# I0814 19:29:42.970819 15764 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function sigmoid at 0x0000026B9862B798>
# input layer shape:  Tensor("Shape:0", shape=(4,), dtype=int32)
# (100, 150, 150, 3)
# con1 shape:  Tensor("Shape_1:0", shape=(4,), dtype=int32)
# (100, 150, 150, 32)
# pool1 Layer shape:  Tensor("Shape_2:0", shape=(4,), dtype=int32)
# (100, 75, 75, 32)
# local_response_normalization shape:  Tensor("Shape_3:0", shape=(4,), dtype=int32)
# (100, 75, 75, 32)
# con2 Layer shape:  Tensor("Shape_4:0", shape=(4,), dtype=int32)
# (100, 75, 75, 64)
# pool2 Layer shape:  Tensor("Shape_5:0", shape=(4,), dtype=int32)
# (100, 37, 37, 64)
# pool2_flat shape:  Tensor("Shape_6:0", shape=(2,), dtype=int32)
# (100, 87616)
# dense Layer shape:  Tensor("Shape_7:0", shape=(2,), dtype=int32)
# (100, 1024)
# logits Layer shape:  Tensor("Shape_8:0", shape=(2,), dtype=int32)
# (100, 2)
# Train Loss:
# Mode:  train
# I0814 19:29:43.050660 15764 monitored_session.py:240] Graph was finalized.
# I0814 19:29:43.060579 15764 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-2
# I0814 19:29:43.471988 15764 session_manager.py:500] Running local_init_op.
# I0814 19:29:43.476977 15764 session_manager.py:502] Done running local_init_op.
# I0814 19:29:44.079364 15764 basic_session_run_hooks.py:606] Saving checkpoints for 2 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:29:46.363698 15764 basic_session_run_hooks.py:262] loss = 9.544934, step = 2
# I0814 19:30:11.007076 15764 basic_session_run_hooks.py:692] global_step/sec: 4.05795
# I0814 19:30:11.008749 15764 basic_session_run_hooks.py:260] loss = 0.6904468, step = 102 (24.645 sec)
# I0814 19:30:38.499754 15764 basic_session_run_hooks.py:692] global_step/sec: 3.63715
# I0814 19:30:38.571769 15764 basic_session_run_hooks.py:260] loss = 0.77002007, step = 202 (27.563 sec)
# I0814 19:31:05.563574 15764 basic_session_run_hooks.py:692] global_step/sec: 3.69497
# I0814 19:31:05.565570 15764 basic_session_run_hooks.py:260] loss = 0.26373374, step = 302 (26.994 sec)
# I0814 19:31:32.127570 15764 basic_session_run_hooks.py:692] global_step/sec: 3.76449
# I0814 19:31:32.128532 15764 basic_session_run_hooks.py:260] loss = 0.29781044, step = 402 (26.563 sec)
# I0814 19:31:59.040564 15764 basic_session_run_hooks.py:692] global_step/sec: 3.71568
# I0814 19:31:59.042557 15764 basic_session_run_hooks.py:260] loss = 0.3209011, step = 502 (26.914 sec)
# I0814 19:32:26.209401 15764 basic_session_run_hooks.py:692] global_step/sec: 3.68069
# I0814 19:32:26.211395 15764 basic_session_run_hooks.py:260] loss = 0.14162754, step = 602 (27.169 sec)
# I0814 19:32:53.930266 15764 basic_session_run_hooks.py:692] global_step/sec: 3.60739
# I0814 19:32:53.937249 15764 basic_session_run_hooks.py:260] loss = 0.3705395, step = 702 (27.726 sec)
# I0814 19:33:22.225121 15764 basic_session_run_hooks.py:692] global_step/sec: 3.53421
# I0814 19:33:22.227116 15764 basic_session_run_hooks.py:260] loss = 0.25378934, step = 802 (28.290 sec)
# I0814 19:33:53.534984 15764 basic_session_run_hooks.py:692] global_step/sec: 3.19388
# I0814 19:33:53.535948 15764 basic_session_run_hooks.py:260] loss = 0.19445018, step = 902 (31.309 sec)
# I0814 19:34:24.388459 15764 basic_session_run_hooks.py:606] Saving checkpoints for 1002 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:34:26.863212 15764 estimator.py:368] Loss for final step: 0.19556876.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=epochs,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0814 19:34:50.259425 15764 estimator.py:1145] Calling model_fn.
# I0814 19:34:50.376165 15764 estimator.py:1147] Done calling model_fn.
# I0814 19:34:50.397092 15764 evaluation.py:255] Starting evaluation at 2019-08-14T19:34:50Z
# act_func_global:  <function sigmoid at 0x0000026B9862B798>
# input layer shape:  Tensor("Shape:0", shape=(4,), dtype=int32)
# (?, 150, 150, 3)
# con1 shape:  Tensor("Shape_1:0", shape=(4,), dtype=int32)
# (?, 150, 150, 32)
# pool1 Layer shape:  Tensor("Shape_2:0", shape=(4,), dtype=int32)
# (?, 75, 75, 32)
# local_response_normalization shape:  Tensor("Shape_3:0", shape=(4,), dtype=int32)
# (?, 75, 75, 32)
# con2 Layer shape:  Tensor("Shape_4:0", shape=(4,), dtype=int32)
# (?, 75, 75, 64)
# pool2 Layer shape:  Tensor("Shape_5:0", shape=(4,), dtype=int32)
# (?, 37, 37, 64)
# pool2_flat shape:  Tensor("Shape_6:0", shape=(2,), dtype=int32)
# (?, 87616)
# dense Layer shape:  Tensor("Shape_7:0", shape=(2,), dtype=int32)
# (?, 1024)
# logits Layer shape:  Tensor("Shape_8:0", shape=(2,), dtype=int32)
# (?, 2)
# Train Loss:
# I0814 19:34:50.565738 15764 monitored_session.py:240] Graph was finalized.
# I0814 19:34:50.574714 15764 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1002
# I0814 19:34:50.985616 15764 session_manager.py:500] Running local_init_op.
# I0814 19:34:50.994591 15764 session_manager.py:502] Done running local_init_op.
# I0814 19:35:08.428711 15764 evaluation.py:275] Finished evaluation at 2019-08-14-19:35:08
# I0814 19:35:08.429708 15764 estimator.py:2039] Saving dict for global step 1002: accuracy = 0.92096597, global_step = 1002, loss = 0.20090404
# I0814 19:35:08.766806 15764 estimator.py:2099] Saving 'checkpoint_path' summary for global step 1002: Estimator//actfn_convnet_model\model.ckpt-1002
# {'accuracy': 0.92096597, 'loss': 0.20090404, 'global_step': 1002}

# %% [markdown]
# - From our sigmoid function we are achieving 'accuracy': 0.9143798 'loss': 0.23210417

# %% [markdown]
# ## <span style="color:#b80f0f"> tanH function

# %% [markdown]
# <img src="Presentation/tanH.png" width="400" height="200" align="center" >

# %% [markdown]
# `Zero centered`- making it easier to model inputs that
# have strongly negative, neutral, and strongly positive values.
# Otherwise like the Sigmoid function.
# ![image.png](attachment:image.png)

# %%
act_func_global=tf.nn.tanh
print(act_func_global)
is_Swish = False
is_SwishBeta = False
is_First = False
# Out:
# <function tanh at 0x0000027268536558>

# %% [markdown]
# ### Train the model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=epochs,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# W0814 19:45:16.538246 12828 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0814 19:45:16.559189 12828 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0814 19:45:16.561183 12828 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# I0814 19:45:16.569163 12828 estimator.py:1145] Calling model_fn.
# W0814 19:45:16.573153 12828 deprecation.py:323] From <ipython-input-13-e37c3dcb5a46>:24: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0814 19:45:16.576144 12828 deprecation.py:506] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0814 19:45:16.761173 12828 deprecation.py:323] From <ipython-input-13-e37c3dcb5a46>:30: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# act_func_global:  <function tanh at 0x0000027268536558>
# W0814 19:45:16.872905 12828 deprecation.py:323] From <ipython-input-13-e37c3dcb5a46>:75: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0814 19:45:17.109626 12828 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# I0814 19:45:17.182431 12828 estimator.py:1147] Done calling model_fn.
# I0814 19:45:17.184426 12828 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# Train Loss:
# Mode:  train
# I0814 19:45:17.474117 12828 monitored_session.py:240] Graph was finalized.
# I0814 19:45:19.150075 12828 session_manager.py:500] Running local_init_op.
# I0814 19:45:19.155095 12828 session_manager.py:502] Done running local_init_op.
# W0814 19:45:19.166034 12828 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\monitored_session.py:875: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# I0814 19:45:19.737558 12828 basic_session_run_hooks.py:606] Saving checkpoints for 0 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:45:23.824992 12828 basic_session_run_hooks.py:262] probabilities = [[0.7317667  0.26823333]
#  [0.8111057  0.18889421]
#  [0.5703387  0.42966124]
#  [0.5616097  0.43839025]
#  [0.76578647 0.2342135 ]
#  [0.8435719  0.15642814]
#  [0.8486323  0.15136774]
#  [0.42193988 0.5780601 ]
#  [0.7635243  0.23647574]
#  [0.46215037 0.53784966]
#  [0.6605583  0.3394417 ]
#  [0.6136548  0.38634518]
#  [0.7123679  0.2876321 ]
#  [0.7390587  0.26094133]
#  [0.76159185 0.23840815]
#  [0.63317627 0.36682373]
#  [0.7869662  0.21303378]
#  [0.8338706  0.16612945]
#  [0.69959366 0.30040628]
#  [0.83796954 0.16203052]
#  [0.8061475  0.1938525 ]
#  [0.5118957  0.48810425]
#  [0.48404044 0.51595956]
#  [0.65111834 0.3488817 ]
#  [0.793822   0.20617801]
#  [0.8819558  0.11804417]
#  [0.74944544 0.2505546 ]
#  [0.70077336 0.29922667]
#  [0.7163641  0.28363585]
#  [0.83244413 0.16755584]
#  [0.40158373 0.59841627]
#  [0.6713213  0.3286787 ]
#  [0.7484921  0.25150788]
#  [0.6938999  0.30610013]
#  [0.62048984 0.37951013]
#  [0.6422895  0.35771048]
#  [0.7072973  0.29270265]
#  [0.6286016  0.37139836]
#  [0.8258627  0.17413725]
#  [0.8001917  0.19980828]
#  [0.7247635  0.2752365 ]
#  [0.49591917 0.5040808 ]
#  [0.8049812  0.19501881]
#  [0.82065845 0.17934155]
#  [0.79677486 0.20322521]
#  [0.82895756 0.17104238]
#  [0.5574145  0.4425856 ]
#  [0.44438368 0.5556164 ]
#  [0.8089616  0.19103837]
#  [0.8396468  0.16035318]
#  [0.8644002  0.13559979]
#  [0.8749375  0.1250626 ]
#  [0.7773268  0.22267316]
#  [0.8137441  0.1862559 ]
#  [0.84370095 0.15629901]
#  [0.7859292  0.21407084]
#  [0.7453274  0.25467262]
#  [0.77093613 0.22906387]
#  [0.37090698 0.629093  ]
#  [0.7477842  0.2522158 ]
#  [0.6457214  0.35427865]
#  [0.73372513 0.2662749 ]
#  [0.6593796  0.3406204 ]
#  [0.7954783  0.2045217 ]
#  [0.7696212  0.23037884]
#  [0.64672184 0.35327822]
#  [0.7223358  0.27766415]
#  [0.631357   0.36864305]
#  [0.72092015 0.27907988]
#  [0.7459397  0.2540603 ]
#  [0.58857024 0.41142973]
#  [0.766146   0.23385395]
#  [0.8848065  0.11519345]
#  [0.6553264  0.34467363]
#  [0.79453886 0.20546107]
#  [0.55674374 0.44325623]
#  [0.71593386 0.2840661 ]
#  [0.7494897  0.25051028]
#  [0.78620493 0.21379504]
#  [0.6022434  0.3977566 ]
#  [0.8235053  0.17649466]
#  [0.71156895 0.2884311 ]
#  [0.6159373  0.38406268]
#  [0.6663213  0.33367866]
#  [0.7513238  0.24867617]
#  [0.80032384 0.19967613]
#  [0.82535374 0.17464633]
#  [0.8085635  0.19143651]
#  [0.77669126 0.22330876]
#  [0.82931125 0.17068873]
#  [0.77325815 0.2267419 ]
#  [0.7434391  0.25656092]
#  [0.5536044  0.44639558]
#  [0.43214324 0.5678567 ]
#  [0.9221478  0.0778522 ]
#  [0.6242761  0.37572393]
#  [0.7938922  0.20610775]
#  [0.93735635 0.06264366]
#  [0.85856396 0.14143597]
#  [0.66240644 0.33759356]]
# I0814 19:45:23.827983 12828 basic_session_run_hooks.py:262] loss = 0.90152097, step = 0
# I0814 19:45:23.829978 12828 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:45:25.411375 12828 estimator.py:368] Loss for final step: 0.90152097.

# %% [markdown]
# #### Now—without logging each step—set steps=1000 to train the model longer, but in a reasonable time to run this example. Training CNNs is computationally intensive. To increase the accuracy of your model, increase the number of steps passed to train(), like 20,000 steps.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0814 19:45:41.613311 12828 estimator.py:1145] Calling model_fn.
# I0814 19:45:41.765902 12828 estimator.py:1147] Done calling model_fn.
# I0814 19:45:41.767897 12828 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function tanh at 0x0000027268536558>
# Train Loss:
# Mode:  train
# I0814 19:45:41.843695 12828 monitored_session.py:240] Graph was finalized.
# W0814 19:45:41.853668 12828 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# I0814 19:45:41.857657 12828 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1
# W0814 19:45:42.242627 12828 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1066: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# I0814 19:45:42.259582 12828 session_manager.py:500] Running local_init_op.
# I0814 19:45:42.264569 12828 session_manager.py:502] Done running local_init_op.
# I0814 19:45:42.862979 12828 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:45:44.172096 12828 basic_session_run_hooks.py:262] loss = 18.765635, step = 1
# I0814 19:46:08.883708 12828 basic_session_run_hooks.py:692] global_step/sec: 4.04635
# I0814 19:46:08.887697 12828 basic_session_run_hooks.py:260] loss = 1.4863534, step = 101 (24.716 sec)
# I0814 19:46:34.529664 12828 basic_session_run_hooks.py:692] global_step/sec: 3.8994
# I0814 19:46:34.530661 12828 basic_session_run_hooks.py:260] loss = 0.29135957, step = 201 (25.643 sec)
# I0814 19:47:00.365572 12828 basic_session_run_hooks.py:692] global_step/sec: 3.87043
# I0814 19:47:00.367578 12828 basic_session_run_hooks.py:260] loss = 0.28919557, step = 301 (25.837 sec)
# I0814 19:47:25.916229 12828 basic_session_run_hooks.py:692] global_step/sec: 3.91379
# I0814 19:47:25.925205 12828 basic_session_run_hooks.py:260] loss = 0.16242859, step = 401 (25.558 sec)
# I0814 19:47:51.845949 12828 basic_session_run_hooks.py:692] global_step/sec: 3.85658
# I0814 19:47:51.847944 12828 basic_session_run_hooks.py:260] loss = 0.14203073, step = 501 (25.923 sec)
# I0814 19:48:17.794555 12828 basic_session_run_hooks.py:692] global_step/sec: 3.85377
# I0814 19:48:17.795554 12828 basic_session_run_hooks.py:260] loss = 0.17162465, step = 601 (25.948 sec)
# I0814 19:48:44.057601 12828 basic_session_run_hooks.py:692] global_step/sec: 3.80763
# I0814 19:48:44.059597 12828 basic_session_run_hooks.py:260] loss = 0.05922903, step = 701 (26.264 sec)
# I0814 19:49:10.467864 12828 basic_session_run_hooks.py:692] global_step/sec: 3.78641
# I0814 19:49:10.469859 12828 basic_session_run_hooks.py:260] loss = 0.13284595, step = 801 (26.410 sec)
# I0814 19:49:37.243846 12828 basic_session_run_hooks.py:692] global_step/sec: 3.73483
# I0814 19:49:37.256812 12828 basic_session_run_hooks.py:260] loss = 0.030814845, step = 901 (26.787 sec)
# I0814 19:50:03.624320 12828 basic_session_run_hooks.py:606] Saving checkpoints for 1001 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:50:05.120168 12828 estimator.py:368] Loss for final step: 0.024557333.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=epochs,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0814 19:50:14.074667 12828 estimator.py:1145] Calling model_fn.
# I0814 19:50:14.181060 12828 estimator.py:1147] Done calling model_fn.
# I0814 19:50:14.201006 12828 evaluation.py:255] Starting evaluation at 2019-08-14T19:50:14Z
# act_func_global:  <function tanh at 0x0000027268536558>
# Train Loss:
# I0814 19:50:14.284629 12828 monitored_session.py:240] Graph was finalized.
# I0814 19:50:14.295599 12828 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1001
# I0814 19:50:14.686553 12828 session_manager.py:500] Running local_init_op.
# I0814 19:50:14.696526 12828 session_manager.py:502] Done running local_init_op.
# I0814 19:50:32.347410 12828 evaluation.py:275] Finished evaluation at 2019-08-14-19:50:32
# I0814 19:50:32.348407 12828 estimator.py:2039] Saving dict for global step 1001: accuracy = 0.9517014, global_step = 1001, loss = 0.13986957
# I0814 19:50:32.672272 12828 estimator.py:2099] Saving 'checkpoint_path' summary for global step 1001: Estimator//actfn_convnet_model\model.ckpt-1001
# {'accuracy': 0.9517014, 'loss': 0.13986957, 'global_step': 1001}

# %% [markdown]
# ## <span style="color:#b80f0f"> ReLU (Rectified Linear Unit)

# %% [markdown]
# <img src="Presentation/ReLU.png" width="500" height="200" align="center" >

# %% [markdown]
# `Computationally efficient`—allows the network to converge very quickly <br />
# `Non-linear`—although it looks like a linear function, ReLU has a derivative function and allows for backpropagation
# ![image.png](attachment:image.png)

# %%
act_func_global=tf.nn.relu
print(act_func_global)
is_Swish = False
is_SwishBeta = False
is_First = False
# Out:
# <function relu at 0x000001D06984A438>

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=epochs,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# I0814 19:58:11.940913 16992 estimator.py:1145] Calling model_fn.
# I0814 19:58:12.107169 16992 estimator.py:1147] Done calling model_fn.
# I0814 19:58:12.109164 16992 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function relu at 0x000001D06984A438>
# Train Loss:
# Mode:  train
# I0814 19:58:12.188950 16992 monitored_session.py:240] Graph was finalized.
# I0814 19:58:12.252780 16992 session_manager.py:500] Running local_init_op.
# I0814 19:58:12.257767 16992 session_manager.py:502] Done running local_init_op.
# I0814 19:58:12.878107 16992 basic_session_run_hooks.py:606] Saving checkpoints for 0 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:58:14.576347 16992 basic_session_run_hooks.py:262] probabilities = [[0.9728486  0.02715144]
#  [0.955676   0.04432396]
#  [0.9975661  0.00243388]
#  [0.9512329  0.04876712]
#  [0.91345054 0.08654949]
#  [0.99621284 0.00378718]
#  [0.99355847 0.00644151]
#  [0.97947043 0.02052958]
#  [0.9954034  0.00459662]
#  [0.99245244 0.00754758]
#  [0.99512595 0.00487413]
#  [0.988839   0.01116094]
#  [0.9735459  0.02645408]
#  [0.9908608  0.00913911]
#  [0.96720874 0.03279128]
#  [0.974165   0.02583497]
#  [0.98877865 0.01122132]
#  [0.97625184 0.02374818]
#  [0.99927706 0.00072293]
#  [0.9722944  0.02770558]
#  [0.9995485  0.00045143]
#  [0.9960503  0.00394976]
#  [0.98096263 0.0190374 ]
#  [0.99509275 0.00490722]
#  [0.9818763  0.01812377]
#  [0.9629985  0.03700145]
#  [0.9801712  0.01982878]
#  [0.9796735  0.02032646]
#  [0.9312918  0.06870824]
#  [0.98563254 0.01436746]
#  [0.9986298  0.00137023]
#  [0.97019076 0.02980921]
#  [0.9886806  0.01131939]
#  [0.9927999  0.00720017]
#  [0.98629016 0.01370978]
#  [0.9849626  0.01503749]
#  [0.9936447  0.00635524]
#  [0.99155325 0.00844678]
#  [0.9947089  0.00529103]
#  [0.9618706  0.03812939]
#  [0.8792606  0.12073933]
#  [0.9901112  0.00988882]
#  [0.98360586 0.01639408]
#  [0.9850714  0.01492862]
#  [0.9970776  0.0029224 ]
#  [0.9821568  0.01784319]
#  [0.987186   0.01281396]
#  [0.97454834 0.02545171]
#  [0.8990915  0.10090856]
#  [0.975425   0.02457506]
#  [0.9754775  0.02452252]
#  [0.94480383 0.05519621]
#  [0.98680496 0.01319501]
#  [0.9855725  0.0144275 ]
#  [0.95228314 0.04771683]
#  [0.96194017 0.03805987]
#  [0.9956216  0.00437841]
#  [0.97487134 0.02512871]
#  [0.98341423 0.0165858 ]
#  [0.99756217 0.00243785]
#  [0.9652277  0.03477229]
#  [0.9943856  0.00561441]
#  [0.99237376 0.00762619]
#  [0.95522517 0.04477476]
#  [0.9984492  0.00155082]
#  [0.97188324 0.02811674]
#  [0.9946497  0.00535032]
#  [0.99367285 0.00632718]
#  [0.9882108  0.01178919]
#  [0.9908738  0.00912621]
#  [0.9978356  0.00216445]
#  [0.9905695  0.00943048]
#  [0.9521729  0.04782708]
#  [0.98045933 0.01954066]
#  [0.98356783 0.01643223]
#  [0.9990706  0.00092944]
#  [0.98686033 0.01313965]
#  [0.997488   0.00251197]
#  [0.95815533 0.04184461]
#  [0.9905144  0.00948555]
#  [0.9264795  0.07352045]
#  [0.99210644 0.00789364]
#  [0.98270756 0.01729247]
#  [0.9985794  0.00142066]
#  [0.9832139  0.01678604]
#  [0.9961831  0.00381694]
#  [0.9979582  0.00204185]
#  [0.99873346 0.00126653]
#  [0.99057627 0.00942372]
#  [0.9916997  0.00830032]
#  [0.988912   0.01108802]
#  [0.96872395 0.03127607]
#  [0.9856757  0.01432431]
#  [0.9968436  0.00315644]
#  [0.9580062  0.04199384]
#  [0.99786335 0.00213669]
#  [0.99927694 0.00072306]
#  [0.9678159  0.03218407]
#  [0.9995402  0.00045978]
#  [0.9986389  0.00136102]]
# I0814 19:58:14.578341 16992 basic_session_run_hooks.py:262] loss = 2.824221, step = 0
# I0814 19:58:14.579339 16992 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:58:16.258419 16992 estimator.py:368] Loss for final step: 2.824221.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0814 19:58:23.248909 16992 estimator.py:1145] Calling model_fn.
# I0814 19:58:23.398509 16992 estimator.py:1147] Done calling model_fn.
# I0814 19:58:23.400504 16992 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function relu at 0x000001D06984A438>
# Train Loss:
# Mode:  train
# I0814 19:58:23.481289 16992 monitored_session.py:240] Graph was finalized.
# W0814 19:58:23.491285 16992 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# I0814 19:58:23.494530 16992 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1
# W0814 19:58:23.870558 16992 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1066: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# I0814 19:58:23.888476 16992 session_manager.py:500] Running local_init_op.
# I0814 19:58:23.893463 16992 session_manager.py:502] Done running local_init_op.
# I0814 19:58:24.478897 16992 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 19:58:26.367511 16992 basic_session_run_hooks.py:262] loss = 624.29553, step = 1
# I0814 19:58:50.848256 16992 basic_session_run_hooks.py:692] global_step/sec: 4.08468
# I0814 19:58:50.850251 16992 basic_session_run_hooks.py:260] loss = 0.67305505, step = 101 (24.483 sec)
# I0814 19:59:16.394582 16992 basic_session_run_hooks.py:692] global_step/sec: 3.91446
# I0814 19:59:16.396581 16992 basic_session_run_hooks.py:260] loss = 0.62770617, step = 201 (25.546 sec)
# I0814 19:59:41.789671 16992 basic_session_run_hooks.py:692] global_step/sec: 3.93792
# I0814 19:59:41.795195 16992 basic_session_run_hooks.py:260] loss = 0.5799881, step = 301 (25.399 sec)
# I0814 20:00:07.110493 16992 basic_session_run_hooks.py:692] global_step/sec: 3.94916
# I0814 20:00:07.112488 16992 basic_session_run_hooks.py:260] loss = 0.56925696, step = 401 (25.317 sec)
# I0814 20:00:32.634275 16992 basic_session_run_hooks.py:692] global_step/sec: 3.91791
# I0814 20:00:32.638264 16992 basic_session_run_hooks.py:260] loss = 0.46872857, step = 501 (25.526 sec)
# I0814 20:00:58.476167 16992 basic_session_run_hooks.py:692] global_step/sec: 3.86969
# I0814 20:00:58.478161 16992 basic_session_run_hooks.py:260] loss = 0.3207257, step = 601 (25.840 sec)
# I0814 20:01:26.323347 16992 basic_session_run_hooks.py:692] global_step/sec: 3.59103
# I0814 20:01:26.326340 16992 basic_session_run_hooks.py:260] loss = 0.20883615, step = 701 (27.848 sec)
# I0814 20:01:53.388416 16992 basic_session_run_hooks.py:692] global_step/sec: 3.69494
# I0814 20:01:53.391408 16992 basic_session_run_hooks.py:260] loss = 0.16479395, step = 801 (27.065 sec)
# I0814 20:02:19.630634 16992 basic_session_run_hooks.py:692] global_step/sec: 3.81051
# I0814 20:02:19.632629 16992 basic_session_run_hooks.py:260] loss = 0.12900232, step = 901 (26.241 sec)
# I0814 20:02:46.280366 16992 basic_session_run_hooks.py:606] Saving checkpoints for 1001 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 20:02:47.996482 16992 estimator.py:368] Loss for final step: 0.27671117.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=epochs,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0814 20:33:43.511662 16992 estimator.py:1145] Calling model_fn.
# I0814 20:33:43.653283 16992 estimator.py:1147] Done calling model_fn.
# I0814 20:33:43.673230 16992 evaluation.py:255] Starting evaluation at 2019-08-14T20:33:43Z
# act_func_global:  <function relu at 0x000001D06984A438>
# Train Loss:
# I0814 20:33:43.754014 16992 monitored_session.py:240] Graph was finalized.
# I0814 20:33:43.761992 16992 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1001
# I0814 20:33:44.151000 16992 session_manager.py:500] Running local_init_op.
# I0814 20:33:44.158979 16992 session_manager.py:502] Done running local_init_op.
# I0814 20:36:43.964156 16992 evaluation.py:275] Finished evaluation at 2019-08-14-20:36:43
# I0814 20:36:43.965153 16992 estimator.py:2039] Saving dict for global step 1001: accuracy = 0.87705815, global_step = 1001, loss = 0.31893197
# I0814 20:36:43.973132 16992 estimator.py:2099] Saving 'checkpoint_path' summary for global step 1001: Estimator//actfn_convnet_model\model.ckpt-1001
# {'accuracy': 0.87705815, 'loss': 0.31893197, 'global_step': 1001}

# %% [markdown]
# ## <span style="color:#b80f0f"> Leaky ReLU

# %% [markdown]
# <img src="Presentation/leaky_ReLU.png" width="500" height="200" align="center" >

# %% [markdown]
# `Prevents dying ReLU problem`- this variation of ReLU has a small positive slope in the negative area, so it does enable `backpropagation`, even for negative input values.
# Otherwise Like a ReLU![image.png](attachment:image.png)

# %%
act_func_global=tf.nn.leaky_relu
print(act_func_global)
is_Swish = False
is_SwishBeta = False
is_First = False
# Out:
# <function leaky_relu at 0x00000204DAD1F5E8>

# %% [markdown]
# ### Train the model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=20,
    num_epochs=epochs,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# I0814 20:49:31.249326 12428 estimator.py:1145] Calling model_fn.
# act_func_global:  <function leaky_relu at 0x00000204DAD1F5E8>
# Train Loss:
# Mode:  train
# I0814 20:49:31.482702 12428 estimator.py:1147] Done calling model_fn.
# I0814 20:49:31.484697 12428 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0814 20:49:31.555932 12428 monitored_session.py:240] Graph was finalized.
# I0814 20:49:31.608735 12428 session_manager.py:500] Running local_init_op.
# I0814 20:49:31.612724 12428 session_manager.py:502] Done running local_init_op.
# I0814 20:49:32.111390 12428 basic_session_run_hooks.py:606] Saving checkpoints for 0 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 20:49:33.907188 12428 basic_session_run_hooks.py:262] probabilities = [[0.05102539 0.9489746 ]
#  [0.02589398 0.9741061 ]
#  [0.01205697 0.9879431 ]
#  [0.11025948 0.8897405 ]
#  [0.02283157 0.97716844]
#  [0.04392216 0.9560779 ]
#  [0.0080861  0.9919139 ]
#  [0.07329369 0.9267064 ]
#  [0.05696342 0.94303656]
#  [0.01593503 0.984065  ]
#  [0.0308104  0.9691896 ]
#  [0.06874058 0.93125945]
#  [0.09415362 0.9058464 ]
#  [0.01862453 0.98137546]
#  [0.00615604 0.99384403]
#  [0.12427709 0.87572294]
#  [0.00730374 0.9926963 ]
#  [0.01294104 0.98705894]
#  [0.01492646 0.9850735 ]
#  [0.04991787 0.9500822 ]]
# I0814 20:49:33.909182 12428 basic_session_run_hooks.py:262] loss = 1.5444592, step = 0
# I0814 20:49:33.912180 12428 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 20:49:35.697087 12428 estimator.py:368] Loss for final step: 1.5444592.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=10)
# Out:
# I0814 20:49:40.227687 12428 estimator.py:1145] Calling model_fn.
# I0814 20:49:40.388257 12428 estimator.py:1147] Done calling model_fn.
# I0814 20:49:40.391249 12428 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function leaky_relu at 0x00000204DAD1F5E8>
# Train Loss:
# Mode:  train
# I0814 20:49:40.474028 12428 monitored_session.py:240] Graph was finalized.
# I0814 20:49:40.482007 12428 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1
# I0814 20:49:40.871072 12428 session_manager.py:500] Running local_init_op.
# I0814 20:49:40.877054 12428 session_manager.py:502] Done running local_init_op.
# I0814 20:49:41.462521 12428 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 20:49:43.348709 12428 basic_session_run_hooks.py:262] loss = 1355.7267, step = 1
# E0814 20:49:43.910208 12428 basic_session_run_hooks.py:760] Model diverged with loss = NaN.
# ---------------------------------------------------------------------------
# NanLossDuringTrainingError                Traceback (most recent call last)
# <ipython-input-22-2afba4dffb24> in <module>
# ----> 1 actfn_classifier.train(input_fn=train_input_fn, steps=10)
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     365
#     366       saving_listeners = _check_listeners_type(saving_listeners)
# --> 367       loss = self._train_model(input_fn, hooks, saving_listeners)
#     368       logging.info('Loss for final step: %s.', loss)
#     369       return self
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1157     else:
# -> 1158       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1159
#    1160   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1190       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1191                                              hooks, global_step_tensor,
# -> 1192                                              saving_listeners)
#    1193
#    1194   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1482       any_step_done = False
#    1483       while not mon_sess.should_stop():
# -> 1484         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1485         any_step_done = True
#    1486     if not any_step_done:
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1250             feed_dict=feed_dict,
#    1251             options=options,
# -> 1252             run_metadata=run_metadata)
#    1253       except _PREEMPTION_ERRORS as e:
#    1254         logging.info(
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, *args, **kwargs)
#    1351         raise six.reraise(*original_exc_info)
#    1352       else:
# -> 1353         raise six.reraise(*original_exc_info)
#    1354
#    1355
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, *args, **kwargs)
#    1336   def run(self, *args, **kwargs):
#    1337     try:
# -> 1338       return self._sess.run(*args, **kwargs)
#    1339     except _PREEMPTION_ERRORS:
#    1340       raise
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1417               results=outputs[hook] if hook in outputs else None,
#    1418               options=options,
# -> 1419               run_metadata=run_metadata))
#    1420     self._should_stop = self._should_stop or run_context.stop_requested
#    1421
#
# ~\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\basic_session_run_hooks.py in after_run(self, run_context, run_values)
#     759       if self._fail_on_nan_loss:
#     760         logging.error(failure_message)
# --> 761         raise NanLossDuringTrainingError
#     762       else:
#     763         logging.warning(failure_message)
#
# NanLossDuringTrainingError: NaN loss during training.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=epochs,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)

# %% [markdown]
# ## <span style="color:#b80f0f"> Swish

# %% [markdown]
# <img src="Presentation/swish.png" width="500" height="200" align="center" >

# %% [markdown]
# `Swish` is a new, self-gated activation function discovered by researchers at Google.<br />
# Swish mathematical expression: `f(x) = x * σ(x)` <br />
# where `σ(x)= sigmoid function`

# %% [markdown]
# #### Set a activation function

# %%
act_func_global=tf.nn.sigmoid
print(act_func_global)
is_Swish = True
is_SwishBeta = False
is_First = False

def swish_1(x):
    act_func_global = x*tf.nn.sigmoid(x)
    return act_func_global
# Out:
# <function sigmoid at 0x000001F6D5871DC8>

# %% [markdown]
# ### Train the model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=epochs,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# W0814 21:19:03.000870 18132 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# I0814 21:19:03.024807 18132 estimator.py:1145] Calling model_fn.
# act_func_global:  <function sigmoid at 0x000001F6D5871DC8>
# Train Loss:
# Mode:  train
# I0814 21:19:03.262512 18132 estimator.py:1147] Done calling model_fn.
# I0814 21:19:03.264510 18132 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0814 21:19:03.548492 18132 monitored_session.py:240] Graph was finalized.
# I0814 21:19:03.556437 18132 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1001
# W0814 21:19:03.946395 18132 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1066: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# I0814 21:19:03.965395 18132 session_manager.py:500] Running local_init_op.
# I0814 21:19:03.970332 18132 session_manager.py:502] Done running local_init_op.
# I0814 21:19:04.593714 18132 basic_session_run_hooks.py:606] Saving checkpoints for 1001 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 21:19:07.222184 18132 basic_session_run_hooks.py:262] probabilities = [[0.21533203 0.78466797]
#  [0.9898812  0.01011881]
#  [0.00916575 0.9908343 ]
#  [0.03575167 0.9642483 ]
#  [0.02596749 0.9740326 ]
#  [0.06949341 0.9305066 ]
#  [0.00523896 0.99476105]
#  [0.9848985  0.01510152]
#  [0.00557046 0.9944296 ]
#  [0.00314896 0.996851  ]
#  [0.1088766  0.8911234 ]
#  [0.19633341 0.80366665]
#  [0.97249335 0.02750669]
#  [0.9173562  0.08264379]
#  [0.9941338  0.00586621]
#  [0.06775486 0.9322451 ]
#  [0.99730635 0.00269369]
#  [0.9982102  0.00178983]
#  [0.99886656 0.00113344]
#  [0.98515666 0.01484335]
#  [0.015966   0.98403394]
#  [0.00818307 0.99181694]
#  [0.0117135  0.98828644]
#  [0.07397159 0.92602843]
#  [0.0102663  0.98973376]
#  [0.34471527 0.65528476]
#  [0.99355775 0.00644228]
#  [0.00354376 0.9964562 ]
#  [0.03784813 0.9621519 ]
#  [0.5306229  0.46937713]
#  [0.9926414  0.00735859]
#  [0.9814053  0.01859467]
#  [0.01101474 0.9889853 ]
#  [0.03820914 0.96179086]
#  [0.01971546 0.98028445]
#  [0.75027496 0.24972501]
#  [0.99584085 0.00415908]
#  [0.97265923 0.02734072]
#  [0.960296   0.039704  ]
#  [0.9985734  0.00142658]
#  [0.99936146 0.00063858]
#  [0.98534817 0.01465184]
#  [0.21014102 0.789859  ]
#  [0.91364163 0.08635838]
#  [0.12954074 0.87045926]
#  [0.9969869  0.00301303]
#  [0.9353643  0.06463573]
#  [0.99398273 0.00601728]
#  [0.834661   0.16533898]
#  [0.00385704 0.99614304]
#  [0.9181327  0.08186729]
#  [0.6907606  0.30923936]
#  [0.7876173  0.21238264]
#  [0.02639974 0.97360027]
#  [0.9026404  0.09735959]
#  [0.01883134 0.9811686 ]
#  [0.0272297  0.97277033]
#  [0.71300256 0.2869974 ]
#  [0.97690785 0.02309212]
#  [0.01349393 0.98650604]
#  [0.00869795 0.991302  ]
#  [0.996391   0.00360895]
#  [0.9936946  0.00630541]
#  [0.9627947  0.03720527]
#  [0.93657225 0.06342778]
#  [0.04355411 0.9564459 ]
#  [0.8644451  0.13555488]
#  [0.9855165  0.01448345]
#  [0.18101265 0.8189873 ]
#  [0.92678475 0.07321518]
#  [0.00977356 0.9902264 ]
#  [0.9766748  0.02332525]
#  [0.989394   0.01060595]
#  [0.989253   0.010747  ]
#  [0.01491554 0.9850845 ]
#  [0.9741228  0.02587713]
#  [0.04158797 0.95841205]
#  [0.02239233 0.97760767]
#  [0.9974656  0.00253438]
#  [0.9940597  0.0059403 ]
#  [0.21418339 0.7858166 ]
#  [0.93498427 0.06501572]
#  [0.99276465 0.00723534]
#  [0.9965224  0.00347763]
#  [0.5821194  0.41788065]
#  [0.00264661 0.99735343]
#  [0.9968399  0.00316006]
#  [0.31493893 0.68506104]
#  [0.02100036 0.9789996 ]
#  [0.37325564 0.62674433]
#  [0.97859406 0.02140601]
#  [0.8472719  0.15272807]
#  [0.25738278 0.7426172 ]
#  [0.00586062 0.99413943]
#  [0.96437263 0.03562737]
#  [0.938925   0.06107497]
#  [0.9394949  0.06050513]
#  [0.5664693  0.4335307 ]
#  [0.07861719 0.9213828 ]
#  [0.9945945  0.00540547]]
# I0814 21:19:07.224309 18132 basic_session_run_hooks.py:262] loss = 0.1290226, step = 1001
# I0814 21:19:07.226304 18132 basic_session_run_hooks.py:606] Saving checkpoints for 1002 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 21:19:08.839482 18132 estimator.py:368] Loss for final step: 0.1290226.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0814 21:19:10.222872 18132 estimator.py:1145] Calling model_fn.
# I0814 21:19:10.385047 18132 estimator.py:1147] Done calling model_fn.
# I0814 21:19:10.387041 18132 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function sigmoid at 0x000001F6D5871DC8>
# Train Loss:
# Mode:  train
# I0814 21:19:10.466861 18132 monitored_session.py:240] Graph was finalized.
# I0814 21:19:10.475803 18132 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1002
# I0814 21:19:10.873740 18132 session_manager.py:500] Running local_init_op.
# I0814 21:19:10.878727 18132 session_manager.py:502] Done running local_init_op.
# I0814 21:19:11.388364 18132 basic_session_run_hooks.py:606] Saving checkpoints for 1002 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 21:19:13.220816 18132 basic_session_run_hooks.py:262] loss = 0.2252236, step = 1002
# I0814 21:19:37.621562 18132 basic_session_run_hooks.py:692] global_step/sec: 4.09824
# I0814 21:19:37.623558 18132 basic_session_run_hooks.py:260] loss = 0.13116968, step = 1102 (24.403 sec)
# I0814 21:20:02.459449 18132 basic_session_run_hooks.py:692] global_step/sec: 4.02611
# I0814 21:20:02.461445 18132 basic_session_run_hooks.py:260] loss = 0.19843048, step = 1202 (24.838 sec)
# I0814 21:20:27.226547 18132 basic_session_run_hooks.py:692] global_step/sec: 4.03778
# I0814 21:20:27.227545 18132 basic_session_run_hooks.py:260] loss = 0.1412646, step = 1302 (24.766 sec)
# I0814 21:20:52.352513 18132 basic_session_run_hooks.py:692] global_step/sec: 3.97979
# I0814 21:20:52.354507 18132 basic_session_run_hooks.py:260] loss = 0.37192222, step = 1402 (25.127 sec)
# I0814 21:21:19.503902 18132 basic_session_run_hooks.py:692] global_step/sec: 3.68305
# I0814 21:21:19.511363 18132 basic_session_run_hooks.py:260] loss = 0.25434497, step = 1502 (27.157 sec)
# I0814 21:21:48.912507 18132 basic_session_run_hooks.py:692] global_step/sec: 3.40037
# I0814 21:21:48.914501 18132 basic_session_run_hooks.py:260] loss = 0.21769314, step = 1602 (29.403 sec)
# I0814 21:22:18.086490 18132 basic_session_run_hooks.py:692] global_step/sec: 3.42783
# I0814 21:22:18.088483 18132 basic_session_run_hooks.py:260] loss = 0.15763158, step = 1702 (29.174 sec)
# I0814 21:22:43.307719 18132 basic_session_run_hooks.py:692] global_step/sec: 3.96491
# I0814 21:22:43.308717 18132 basic_session_run_hooks.py:260] loss = 0.116578884, step = 1802 (25.220 sec)
# I0814 21:23:11.290842 18132 basic_session_run_hooks.py:692] global_step/sec: 3.57346
# I0814 21:23:11.292836 18132 basic_session_run_hooks.py:260] loss = 0.2300213, step = 1902 (27.984 sec)
# I0814 21:23:37.260877 18132 basic_session_run_hooks.py:606] Saving checkpoints for 2002 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 21:23:38.977006 18132 estimator.py:368] Loss for final step: 0.22424196.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=epochs,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# W0814 21:25:42.769409  1940 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0814 21:25:42.771404  1940 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# I0814 21:25:42.780380  1940 estimator.py:1145] Calling model_fn.
# W0814 21:25:42.785366  1940 deprecation.py:323] From <ipython-input-16-e37c3dcb5a46>:24: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0814 21:25:42.788358  1940 deprecation.py:506] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0814 21:25:42.953365  1940 deprecation.py:323] From <ipython-input-16-e37c3dcb5a46>:30: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# act_func_global:  <function relu at 0x000002161CEE3A68>
# input layer shape:  Tensor("Shape:0", shape=(4,), dtype=int32)
# (?, 150, 150, 3)
# con1 shape:  Tensor("Shape_1:0", shape=(4,), dtype=int32)
# (?, 150, 150, 32)
# W0814 21:25:43.073243  1940 deprecation.py:323] From <ipython-input-16-e37c3dcb5a46>:75: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# pool1 Layer shape:  Tensor("Shape_2:0", shape=(4,), dtype=int32)
# (?, 75, 75, 32)
# local_response_normalization shape:  Tensor("Shape_3:0", shape=(4,), dtype=int32)
# (?, 75, 75, 32)
# con2 Layer shape:  Tensor("Shape_4:0", shape=(4,), dtype=int32)
# (?, 75, 75, 64)
# pool2 Layer shape:  Tensor("Shape_5:0", shape=(4,), dtype=int32)
# (?, 37, 37, 64)
# pool2_flat shape:  Tensor("Shape_6:0", shape=(2,), dtype=int32)
# (?, 87616)
# W0814 21:25:43.302630  1940 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# I0814 21:25:43.326565  1940 estimator.py:1147] Done calling model_fn.
# I0814 21:25:43.349542  1940 evaluation.py:255] Starting evaluation at 2019-08-14T21:25:43Z
# I0814 21:25:43.426298  1940 monitored_session.py:240] Graph was finalized.
# dense Layer shape:  Tensor("Shape_7:0", shape=(2,), dtype=int32)
# (?, 1024)
# logits Layer shape:  Tensor("Shape_8:0", shape=(2,), dtype=int32)
# (?, 2)
# Train Loss:
# W0814 21:25:44.869074  1940 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# I0814 21:25:44.873064  1940 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-2002
# I0814 21:25:45.521192  1940 session_manager.py:500] Running local_init_op.
# I0814 21:25:45.529170  1940 session_manager.py:502] Done running local_init_op.
# W0814 21:25:45.543133  1940 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\monitored_session.py:875: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# I0814 21:26:03.498889  1940 evaluation.py:275] Finished evaluation at 2019-08-14-21:26:03
# I0814 21:26:03.499922  1940 estimator.py:2039] Saving dict for global step 2002: accuracy = 0.90010977, global_step = 2002, loss = 1.307222
# I0814 21:26:03.788604  1940 estimator.py:2099] Saving 'checkpoint_path' summary for global step 2002: Estimator//actfn_convnet_model\model.ckpt-2002
# {'accuracy': 0.90010977, 'loss': 1.307222, 'global_step': 2002}

# %% [markdown]
# ## <span style="color:#b80f0f"> Swish-Beta

# %% [markdown]
# <img src="Presentation/swish_1.png" width="500" height="200" align="center" >

# %% [markdown]
# #### Set a activation function

# %%
act_func_global=tf.nn.sigmoid
print(act_func_global)
is_Swish = False
is_SwishBeta = True
is_First = False

def swish_beta(x):
    beta=tf.Variable(initial_value=1.0,trainable=True,name='swish_beta')
    print('beta: ',beta)
    act_func_global = x*tf.nn.sigmoid(beta*x) #trainable parameter beta
    print('act_func_global: ',act_func_global)
    return act_func_global
# Out:
# <function sigmoid at 0x000002161D173DC8>

# %% [markdown]
# ### Train the model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=50,
    num_epochs=epochs,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# W0814 21:35:52.521399  1940 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# I0814 21:35:52.550356  1940 estimator.py:1145] Calling model_fn.
# act_func_global:  <function sigmoid at 0x000002161D173DC8>
# beta:  <tf.Variable 'swish_beta:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_1:0", shape=(?, 150, 150, 3), dtype=float32)
# beta:  <tf.Variable 'swish_beta_1:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_3:0", shape=(?, 75, 75, 32), dtype=float32)
# beta:  <tf.Variable 'swish_beta_2:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_5:0", shape=(?, 87616), dtype=float32)
# Train Loss:
# Mode:  train
# I0814 21:35:52.801650  1940 estimator.py:1147] Done calling model_fn.
# I0814 21:35:52.803645  1940 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0814 21:35:53.105041  1940 monitored_session.py:240] Graph was finalized.
# I0814 21:35:53.176850  1940 session_manager.py:500] Running local_init_op.
# I0814 21:35:53.181805  1940 session_manager.py:502] Done running local_init_op.
# I0814 21:35:53.844636  1940 basic_session_run_hooks.py:606] Saving checkpoints for 0 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 21:35:55.930674  1940 basic_session_run_hooks.py:262] probabilities = [[0.7780875  0.22191246]
#  [0.78783506 0.21216494]
#  [0.7919626  0.2080374 ]
#  [0.7824107  0.21758935]
#  [0.7833426  0.21665746]
#  [0.77578926 0.22421074]
#  [0.79190934 0.20809063]
#  [0.78469545 0.21530452]
#  [0.7816083  0.21839175]
#  [0.7782471  0.22175287]
#  [0.79407746 0.20592254]
#  [0.78698117 0.21301879]
#  [0.7863959  0.2136041 ]
#  [0.7781119  0.22188808]
#  [0.7886022  0.21139781]
#  [0.7806816  0.21931836]
#  [0.791463   0.208537  ]
#  [0.7789829  0.22101709]
#  [0.77701247 0.22298753]
#  [0.7839829  0.21601714]
#  [0.7753522  0.22464788]
#  [0.77737623 0.22262375]
#  [0.78555876 0.2144412 ]
#  [0.7805488  0.21945122]
#  [0.79407924 0.20592073]
#  [0.7803697  0.21963033]
#  [0.78282243 0.21717753]
#  [0.7739095  0.22609043]
#  [0.777553   0.222447  ]
#  [0.7895609  0.21043912]
#  [0.7817728  0.2182272 ]
#  [0.7802454  0.2197546 ]
#  [0.78272486 0.21727517]
#  [0.7809436  0.21905643]
#  [0.7886074  0.21139255]
#  [0.7943684  0.20563164]
#  [0.78586966 0.21413031]
#  [0.77841747 0.22158249]
#  [0.7777691  0.2222309 ]
#  [0.77167296 0.22832707]
#  [0.78912836 0.2108716 ]
#  [0.77955216 0.2204478 ]
#  [0.78094316 0.21905681]
#  [0.78826785 0.21173216]
#  [0.7794449  0.22055514]
#  [0.7878269  0.21217313]
#  [0.7816847  0.21831527]
#  [0.78710437 0.21289566]
#  [0.78922975 0.21077028]
#  [0.78866315 0.2113368 ]]
# I0814 21:35:55.931669  1940 basic_session_run_hooks.py:262] loss = 0.8863531, step = 0
# I0814 21:35:55.933664  1940 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 21:35:57.190462  1940 estimator.py:368] Loss for final step: 0.8863531.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0814 21:36:03.133990  1940 estimator.py:1145] Calling model_fn.
# I0814 21:36:03.304533  1940 estimator.py:1147] Done calling model_fn.
# I0814 21:36:03.306566  1940 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function sigmoid at 0x000002161D173DC8>
# beta:  <tf.Variable 'swish_beta:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_1:0", shape=(?, 150, 150, 3), dtype=float32)
# beta:  <tf.Variable 'swish_beta_1:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_3:0", shape=(?, 75, 75, 32), dtype=float32)
# beta:  <tf.Variable 'swish_beta_2:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_5:0", shape=(?, 87616), dtype=float32)
# Train Loss:
# Mode:  train
# I0814 21:36:03.389377  1940 monitored_session.py:240] Graph was finalized.
# I0814 21:36:03.398321  1940 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-1
# W0814 21:36:03.773594  1940 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\saver.py:1066: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# I0814 21:36:03.791598  1940 session_manager.py:500] Running local_init_op.
# I0814 21:36:03.796533  1940 session_manager.py:502] Done running local_init_op.
# I0814 21:36:04.488681  1940 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 21:36:05.648750  1940 basic_session_run_hooks.py:262] loss = 6.332838, step = 1
# I0814 21:36:18.858990  1940 basic_session_run_hooks.py:692] global_step/sec: 7.57046
# I0814 21:36:18.859986  1940 basic_session_run_hooks.py:260] loss = 0.81356436, step = 101 (13.211 sec)
# I0814 21:36:32.050686  1940 basic_session_run_hooks.py:692] global_step/sec: 7.57995
# I0814 21:36:32.052646  1940 basic_session_run_hooks.py:260] loss = 1.3125035, step = 201 (13.193 sec)
# I0814 21:36:45.388469  1940 basic_session_run_hooks.py:692] global_step/sec: 7.4975
# I0814 21:36:45.391462  1940 basic_session_run_hooks.py:260] loss = 0.35696518, step = 301 (13.339 sec)
# I0814 21:36:59.407495  1940 basic_session_run_hooks.py:692] global_step/sec: 7.13316
# I0814 21:36:59.409489  1940 basic_session_run_hooks.py:260] loss = 0.35985047, step = 401 (14.018 sec)
# I0814 21:37:13.415275  1940 basic_session_run_hooks.py:692] global_step/sec: 7.13889
# I0814 21:37:13.417239  1940 basic_session_run_hooks.py:260] loss = 0.32967216, step = 501 (14.008 sec)
# I0814 21:37:27.199006  1940 basic_session_run_hooks.py:692] global_step/sec: 7.25493
# I0814 21:37:27.201000  1940 basic_session_run_hooks.py:260] loss = 0.22295508, step = 601 (13.784 sec)
# I0814 21:37:40.875428  1940 basic_session_run_hooks.py:692] global_step/sec: 7.31185
# I0814 21:37:40.877423  1940 basic_session_run_hooks.py:260] loss = 0.25322902, step = 701 (13.676 sec)
# I0814 21:37:54.576545  1940 basic_session_run_hooks.py:692] global_step/sec: 7.29868
# I0814 21:37:54.586540  1940 basic_session_run_hooks.py:260] loss = 0.18299165, step = 801 (13.709 sec)
# I0814 21:38:07.461393  1940 basic_session_run_hooks.py:606] Saving checkpoints for 894 into Estimator//actfn_convnet_model\model.ckpt.
# I0814 21:38:08.652237  1940 estimator.py:368] Loss for final step: 0.25645024.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=epochs,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0814 21:45:54.600180  1940 estimator.py:1145] Calling model_fn.
# I0814 21:45:54.720215  1940 estimator.py:1147] Done calling model_fn.
# I0814 21:45:54.740162  1940 evaluation.py:255] Starting evaluation at 2019-08-14T21:45:54Z
# act_func_global:  <function sigmoid at 0x000002161D173DC8>
# beta:  <tf.Variable 'swish_beta:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_1:0", shape=(?, 150, 150, 3), dtype=float32)
# beta:  <tf.Variable 'swish_beta_1:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_3:0", shape=(?, 75, 75, 32), dtype=float32)
# beta:  <tf.Variable 'swish_beta_2:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_5:0", shape=(?, 87616), dtype=float32)
# Train Loss:
# I0814 21:45:54.821943  1940 monitored_session.py:240] Graph was finalized.
# I0814 21:45:54.831043  1940 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model\model.ckpt-894
# I0814 21:45:55.238788  1940 session_manager.py:500] Running local_init_op.
# I0814 21:45:55.247787  1940 session_manager.py:502] Done running local_init_op.
# I0814 21:46:11.267903  1940 evaluation.py:275] Finished evaluation at 2019-08-14-21:46:11
# I0814 21:46:11.268901  1940 estimator.py:2039] Saving dict for global step 894: accuracy = 0.81339186, global_step = 894, loss = 0.41924772
# I0814 21:46:11.274879  1940 estimator.py:2099] Saving 'checkpoint_path' summary for global step 894: Estimator//actfn_convnet_model\model.ckpt-894
# {'accuracy': 0.81339186, 'loss': 0.41924772, 'global_step': 894}
