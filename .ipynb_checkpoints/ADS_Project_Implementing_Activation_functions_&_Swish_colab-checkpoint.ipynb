# %% [markdown]
# # Implementing and Comparing Activations functions

# %% [markdown]
# ## Abstract
#
# Neural network activation functions are a crucial component of deep learning. Activation functions determine the output of a deep learning model, its accuracy, and also the computational efficiency of training a model—which can make or break a large scale neural network. Activation functions also have a major effect on the neural network’s ability to converge and the convergence speed.<br />
# <br />
# In this project, I have implemented various Activation functions like `sigmoid, tanH, ReLU, Leaky ReLU, Parametric ReLU, and Swish` etc. Compared their outputs, accuracy, loss along with the time taken by each function to converge. <br />
# <br />
# I have created `Convolutional Neural Network(CNN)` model that is used across all Activation functions to maintain consistency and validness. The CNN model is implemented using `TensorFlow` and the data is acquired from `Intel Image Classification` competition which held on Analyticsvidya.com. <br />
# <br />
# Aim of this project is to elaborate the importance of different activation functions

# %% [markdown]
# ### Import the required libraries

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import re
import tensorflow as tf

tf.logging.set_verbosity(tf.logging.INFO)
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math

#Keras libraries
import keras
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import *
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools 
import matplotlib.pyplot as plt
import seaborn as sn                        
from sklearn.utils import shuffle
import os
import cv2

from IPython.display import display 
from PIL import Image
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### TensorFlow Version working with

# %%
tf.__version__
# Out:
# '1.14.0'

# %% [markdown]
# #### Here's our 6 categories that we have to classify.

# %%
# class_names = ['mountain', 'street', 'glacier', 'buildings', 'sea', 'forest']
# class_names_label = {'mountain': 0,
#                     'street' : 1,
#                     'glacier' : 2,
#                     'buildings' : 3,
#                     'sea' : 4,
#                     'forest' : 5
#                     }
# nb_classes = 6
class_names = ['buildings', 'forest']
class_names_label = {'buildings': 0,
                    'forest' : 1
                    }
nb_classes = 2

# %%
import zipfile
import io
# Unzip Train
# !unzip /content/seg_train.zip

# %%
# !rm -rf /content/seg_train     #delete folder
# !unzip /content/seg_test3.zip

# %% [markdown]
# #### Load the data

# %%
# For coloab path


def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 10,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['/content/seg_train/seg_train', '/content/seg_test/seg_test']
    size = (150,150)
    output = []
    for dataset in datasets:
#         directory = "C://Users//kaila//OneDrive//Desktop//ADS//Project_Implementing_Activations_functions_and_Swish//Dataset//" + dataset
        directory = dataset
        images = []
        labels = []
        for folder in os.listdir(directory):
            print(folder)
            curr_label = class_names_label[folder]
            for file in os.listdir(directory + "/" + folder):
                img_path = directory + "/" + folder + "/" + file
                curr_img = cv2.imread(img_path)
                curr_img = cv2.resize(curr_img, size)
                images.append(curr_img)
                labels.append(curr_label)
        images, labels = shuffle(images, labels)    
        images = np.array(images, dtype = 'float32') 
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %% [markdown]
# `load_data functon:`
# - It load Train and Test image data
# - Read the images using openCV
# - Since in competion its asked for image to be of size 150*150 so I am rescalling it, it will help in faster convergence.
# - Append images and labels to their respective list
# - shuffling the data
# - Converting images and labels to Numpy array so it will be easier to normalize the later

# %% [markdown]
# ### Loading Training and Evaluation data

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# buildings
# forest
# buildings
# forest

# %%
train_data = train_images
train_labels = train_labels.astype(np.int32)  # not required

eval_data = test_images
eval_labels = test_labels.astype(np.int32)  # not required

# %%
print ("Number of training examples: " + str(train_labels.shape[0]))
print ("Number of testing examples: " + str(test_labels.shape[0]))
print ("Each image is of size: " + str(train_images.shape[1:]))
# Out:
# Number of training examples: 4462
# Number of testing examples: 911
# Each image is of size: (150, 150, 3)

# %% [markdown]
# - Our image dataset contain 14034 Training and 3000 test images 150*150 size of 3 channel (i.e colored RGB images)

# %% [markdown]
# #### Lets plot a pie chart of image distribution of 6 type

# %%
# Plot a pie chart
sizes = np.bincount(train_labels)
# explode = (0, 0, 0, 0, 0, 0)  
explode = (0, 0)  
plt.pie(sizes, explode=explode, labels=class_names,
autopct='%1.2f%%', shadow=True, startangle=150)
plt.axis('equal')
plt.title('Proportion of each observed category')

plt.show()

# %% [markdown]
# #### Its good practice to Normalize pixel values to be between 0 and 1

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
print('x_images.shape =', train_images.shape)
print('x_images.min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(train_images.min(),
                        train_images.mean(), train_images.std(), train_images.max()))
print('')
print('y_images.shape =', test_images.shape)
print('y_images.min/mean/std/max = %.2f/%.2f/%.2f/%.2f'%(test_images.min(),
                        test_images.mean(), test_images.std(), test_images.max()))
# Out:
# x_images.shape = (4462, 150, 150, 3)
# x_images.min/mean/std/max = 0.00/0.38/0.28/1.00
#
# y_images.shape = (911, 150, 150, 3)
# y_images.min/mean/std/max = 0.00/0.38/0.28/1.00

# %% [markdown]
# #### Plot some random images from our dataset

# %%
fig = plt.figure(figsize=(20,10))
fig.suptitle("Some examples of images of the dataset", fontsize=16)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ### Create global variable to set Activation function

# %%
act_func_global = tf.nn.relu       #Here I set it default to relu so that our variable became of that type
print(act_func_global)
is_Swish = False
print('is a Swish function: ',is_Swish)
is_SwishBeta = False
print('is a Swish Beta function: ',is_SwishBeta)
is_First = True
print('is a first function: ',is_Swish)
b_size=500
print('batch size: ',b_size)
# Out:
# <function relu at 0x7f9c5ecc9400>
# is a Swish function:  False
# is a Swish Beta function:  False
# is a first function:  False
# batch size:  500

# %% [markdown]
# ### Create CNN Model for different Activation Functions

# %%
def cnn_model_fn(features, labels, mode):
    
    """Model function for CNN."""
    # act_func=tf.nn.relu
    
    print('act_func_global: ',act_func_global)
    
    # Input Layer
    input_layer = tf.reshape(features["x"], [-1, 150, 150, 3])       #All of our images are of size 150*150
    if is_First == True:
        print('input layer shape: ',tf.shape(input_layer))
        print(input_layer.get_shape())
    
    if is_Swish == True:
        swish_1(input_layer)
    if is_SwishBeta == True:
        swish_beta(input_layer)
    # Convolutional Layer #1
    conv1 = tf.layers.conv2d(
      inputs=input_layer,
      filters=32,
      kernel_size=[3, 3],
      padding="same",
      use_bias=True,
      activation=act_func_global)
    if is_First == True:
        print('con1 shape: ',tf.shape(conv1))
        print(conv1.get_shape())

    # Pooling Layer #1
    pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)
    if is_First == True:
        print('pool1 Layer shape: ',tf.shape(pool1))
        print(pool1.get_shape())
    
    #local_response_normalization
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 3.0, beta=0.75, name='norm1')
    if is_First == True:
        print('local_response_normalization shape: ',tf.shape(norm1))
        print(norm1.get_shape())
    
    if is_Swish == True:
        swish_1(norm1)
    if is_SwishBeta == True:
        swish_beta(norm1)
    # Convolutional Layer #2 and Pooling Layer #2
    conv2 = tf.layers.conv2d(
      inputs=norm1,
      filters=64,
      kernel_size=[3, 3],
      padding="same",
      activation=act_func_global)
    if is_First == True:
        print('con2 Layer shape: ',tf.shape(conv2))
        print(conv2.get_shape())
    
    pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)
    if is_First == True:
        print('pool2 Layer shape: ',tf.shape(pool2))
        print(pool2.get_shape())
    
    
    # We'll flatten our feature map (pool2) to shape [batch_size, features], so that our tensor has only two dimensions
    # pool2_flat = tf.reshape(pool2, [-1, 37 * 37 * 64])
    pool2_flat = tf.reshape(pool2, [-1, pool2.get_shape()[1] * pool2.get_shape()[2] * 64])
    if is_First == True:
        print('pool2_flat shape: ',tf.shape(pool2_flat))
        print(pool2_flat.get_shape())
    
    if is_Swish == True:
        swish_1(pool2_flat)
        
    if is_SwishBeta == True:
        swish_beta(pool2_flat)
    # Dense Layer
    dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=act_func_global)
    if is_First == True:
        print('dense Layer shape: ',tf.shape(dense))
        print(dense.get_shape())
    
    # Drop the 10% of the input
#     dropout = tf.layers.dropout(inputs=dense, rate=0.1, training=mode == tf.estimator.ModeKeys.TRAIN)
#     print('dropout Regularizatin shape: ',tf.shape(dropout))
#     print(dropout.get_shape())
    
        
    # Logits Layer
    logits = tf.layers.dense(inputs=dense, units=2) # Here we have 6 Classes
    if is_First == True:
        print('logits Layer shape: ',tf.shape(logits))
        print(logits.get_shape())
    
    predictions = {
      # Generate predictions (for PREDICT and EVAL mode)
      "classes": tf.argmax(input=logits, axis=1),
      # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
      # `logging_hook`.
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
    }

    if mode == tf.estimator.ModeKeys.PREDICT:
        print('Mode: ',mode)
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    # Calculate Loss (for both TRAIN and EVAL modes)
    # loss = tf.losses.sigmoid_cross_entropy(multi_class_labels=labels, logits=logits, weights=1.0)
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits, weights=1.0)

    # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
#         optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
        optimizer = tf.train.AdamOptimizer(learning_rate=0.01, beta1=0.9, epsilon=1e-08)

        # print("Optimizer: ",optimizer)
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
        # print('train_op: ',train_op)
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    print(' ')
    # Add evaluation metrics (for EVAL mode)
    eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(
          labels=labels, predictions=predictions["classes"])
    }
    
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %% [markdown]
# <img src="CNN-Model.jpeg" width="1000" align="Left" >

# %% [markdown]
# #### Model Explanation:
# <span style="color:#096694" >
#
# - A `cnn_model_fn` function takes features(i.e Input Image data), labels(i.e Image categorie), and mode(i.e Train, Test, Validate) as a input
# - I have created global variable `act_func_global` of type `tf.nn` and can be set each time for diffrent activation function
# - 1st layer is `input layer` which takes features and dimention as imput and outputs `4D-tensor` of size `(batch_size, 150 X 150 X 3)`
# - 2nd layer is Convolutional Layer- `conv1`, with `32` filters and kernel size `3X3` which ouputs 4D-tensor of size `(batch_size, 150 X 150 X 32)` and there is no dimension reduction since we are using `same` padding
# - 3rd layer is Pooling Layer- `pool1`, with pool size `2X2`, strides = `2` and which ouputs 4D-tensor of size `(batch_size, 75 X 75 X 32)` and there is dimension reduction
# - 4th layer is Normalization- `local_response_normalization`, Here the 4-D `input` tensor is treated as a 3-D array of 1-D vectors (along the last dimension), and each vector is normalized independently.  Within a given vector, each component is divided by the weighted, squared sum of inputs within `depth_radius`
# - 5th layer is Convolutional Layer- `conv2`, with `64` filters and kernel size `3X3` which ouputs 4D-tensor of size `(batch_size, 75 X 75 X 64)` and there is no dimension reduction since we are using `same` padding
# - 6th layer is Pooling Layer- `pool2`, with pool size `2X2`, strides = `2` and which ouputs 4D-tensor of size `(batch_size, 37 X 37 X 64)` and there is dimension reduction
# - 7th layer is FLatten Layer- `pool2_flat`, which flatten our feature map (pool2) to shape [batch_size, features], so that our tensor has only two dimensions. The `2-D tensor` size became (batch_size, 87616)
# - 8th layer is Dense/Fully connected layer- `dense`, which implements the operation:`outputs = activation(inputs * kernel + bias)`. It outputs the tensor of size (batch_size, 1024)
# - 9th layer is Logits/Dense Layer- `logits`, Here we reduce the size of neurons to output as 6, since we have `6 classes/labels to predict`. The output size of this layer is (batch_size,6)
# - For predictions I am using `softmax` function on outputs from `tf.nn.softmax`.
# - To Calculate Loss (for both TRAIN and EVAL modes) I am using `sparse_softmax_cross_entropy` (i.e Cross-entropy loss). Here, `weights` acts as a coefficient for the loss. If a scalar is provided, then the loss is simply scaled by the given value. If weights is a tensor of shape `[batch_size]`, then the loss weights apply to each corresponding sample.
# - To `optimise` the predictions i am usning `GradientDescentOptimizer` with `learn rate 0.01` that can be tweak futher for better accuracy
# <br />
# <br />
# - In the reshape() operation above, the -1 signifies that the batch_size dimension will be dynamically calculated based on the number of examples in our input data.

# %% [markdown]
# ### Create the Estimator
# Estimator (a TensorFlow class for performing high-level model training, evaluation, and inference) for our model.

# %%
# Create the Estimator

def estimator_path(function_name):
    actfn_classifier = tf.estimator.Estimator(model_fn=cnn_model_fn, 
            model_dir="Estimator//actfn_convnet_model//"+ function_name)

# %% [markdown]
# - The model_fn argument specifies the model function to use for training, evaluation, and prediction; we pass it the actfn_classifier we created
# - The model_dir argument specifies the directory where model data (checkpoints) will be saved

# %% [markdown]
# ### Set Up a Logging Hook

# %%
# Set up logging for predictions
tensors_to_log = {"probabilities": "softmax_tensor"}

logging_hook = tf.train.LoggingTensorHook(
    tensors=tensors_to_log, every_n_iter=50)

# %% [markdown]
# - Since CNNs can take a while to train, let's set up some logging so we can track progress during training
# - We set every_n_iter=50, which specifies that probabilities should be logged after every 50 steps of training.

# %% [markdown]
# ## <span style="color:#b80f0f"> Sigmoid Function

# %% [markdown]
# <img src="Presentation/sigmoid.png" width="400" height="200" align="center" >

# %% [markdown]
# `Smooth gradient`, preventing “jumps” in output values.<br />
# `Output values bound` between 0 and 1, normalizing the output of each neuron.<br />
# `Clear predictions`- For X above 2 or below -2, tends to bring the Y value (the prediction) to the edge of the curve, very close to 1 or 0. This enables clear predictions.

# %% [markdown]
# #### Set a activation function

# %%
act_func_global=tf.nn.sigmoid
estimator_path='sigmoid'
print(act_func_global)
is_Swish = False
is_First = True
# Out:
# <function sigmoid at 0x7f9c5ec00f28>

# %% [markdown]
# ### Train the Model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=None,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# I0815 04:49:52.712545 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 04:49:52.892694 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 04:49:52.895509 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# input layer shape:  Tensor("Shape:0", shape=(4,), dtype=int32)
# (500, 150, 150, 3)
# con1 shape:  Tensor("Shape_1:0", shape=(4,), dtype=int32)
# (500, 150, 150, 32)
# pool1 Layer shape:  Tensor("Shape_2:0", shape=(4,), dtype=int32)
# (500, 75, 75, 32)
# local_response_normalization shape:  Tensor("Shape_3:0", shape=(4,), dtype=int32)
# (500, 75, 75, 32)
# con2 Layer shape:  Tensor("Shape_4:0", shape=(4,), dtype=int32)
# (500, 75, 75, 64)
# pool2 Layer shape:  Tensor("Shape_5:0", shape=(4,), dtype=int32)
# (500, 37, 37, 64)
# pool2_flat shape:  Tensor("Shape_6:0", shape=(2,), dtype=int32)
# (500, 87616)
# dense Layer shape:  Tensor("Shape_7:0", shape=(2,), dtype=int32)
# (500, 1024)
# logits Layer shape:  Tensor("Shape_8:0", shape=(2,), dtype=int32)
# (500, 2)
# Train Loss:
# Mode:  train
# I0815 04:49:53.156732 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 04:49:53.162725 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-1
# I0815 04:49:53.448321 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 04:49:53.453764 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 04:49:53.610781 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 04:49:54.966436 140310752536448 basic_session_run_hooks.py:262] probabilities = [[0.99753463 0.00246531]
#  [0.99728036 0.00271956]
#  [0.99747473 0.00252529]
#  [0.9974003  0.00259972]
#  [0.9972676  0.00273247]
#  [0.9975842  0.00241574]
#  [0.9972742  0.00272575]
#  [0.9972332  0.00276683]
#  [0.9972894  0.00271066]
#  [0.99757856 0.00242151]
#  [0.99756986 0.00243009]
#  [0.99740237 0.00259757]
#  [0.9972511  0.00274893]
#  [0.997399   0.00260099]
#  [0.9975937  0.00240627]
#  [0.997542   0.00245795]
#  [0.9974825  0.00251749]
#  [0.9974865  0.00251357]
#  [0.997424   0.00257604]
#  [0.9971564  0.00284357]
#  [0.9975255  0.00247449]
#  [0.99773467 0.00226537]
#  [0.9974955  0.00250453]
#  [0.9976031  0.00239691]
#  [0.99729866 0.00270132]
#  [0.9974833  0.00251667]
#  [0.9973454  0.00265467]
#  [0.99741167 0.00258841]
#  [0.9974705  0.00252955]
#  [0.99727005 0.00272988]
#  [0.99750215 0.0024978 ]
#  [0.9973224  0.00267764]
#  [0.9977081  0.00229191]
#  [0.99725395 0.0027461 ]
#  [0.9974726  0.00252743]
#  [0.99756914 0.00243084]
#  [0.9973686  0.00263137]
#  [0.99749136 0.00250863]
#  [0.99754375 0.0024562 ]
#  [0.99734807 0.00265191]
#  [0.99757856 0.00242142]
#  [0.99758196 0.00241805]
#  [0.99743026 0.0025697 ]
#  [0.9976974  0.00230254]
#  [0.99736637 0.00263369]
#  [0.99747294 0.00252699]
#  [0.99713445 0.00286554]
#  [0.997416   0.0025839 ]
#  [0.99745244 0.00254751]
#  [0.99744654 0.00255354]
#  [0.99751735 0.00248265]
#  [0.9973895  0.00261047]
#  [0.9976528  0.00234715]
#  [0.9974757  0.00252434]
#  [0.9976561  0.00234385]
#  [0.9974596  0.00254049]
#  [0.99763334 0.00236662]
#  [0.99767953 0.00232048]
#  [0.9975091  0.00249091]
#  [0.99730706 0.00269293]
#  [0.9972114  0.00278863]
#  [0.9974245  0.00257549]
#  [0.997654   0.00234596]
#  [0.99729484 0.00270516]
#  [0.99708277 0.00291726]
#  [0.997439   0.00256095]
#  [0.997171   0.00282904]
#  [0.9975902  0.00240982]
#  [0.99743325 0.00256681]
#  [0.9976464  0.00235358]
#  [0.9975508  0.00244922]
#  [0.9976502  0.00234976]
#  [0.99755716 0.00244276]
#  [0.9977738  0.00222611]
#  [0.9975188  0.00248119]
#  [0.99767464 0.00232533]
#  [0.9974673  0.00253276]
#  [0.9976545  0.00234555]
#  [0.9974624  0.00253761]
#  [0.9976584  0.00234163]
#  [0.9974853  0.00251474]
#  [0.99758947 0.00241053]
#  [0.9976311  0.00236887]
#  [0.9974528  0.00254717]
#  [0.9977719  0.0022281 ]
#  [0.99729306 0.00270697]
#  [0.99749076 0.0025093 ]
#  [0.99738675 0.00261329]
#  [0.9975898  0.00241021]
#  [0.9974706  0.00252946]
#  [0.99747235 0.00252759]
#  [0.9973973  0.00260272]
#  [0.99757105 0.00242891]
#  [0.9971836  0.00281638]
#  [0.99718386 0.00281614]
#  [0.997652   0.00234802]
#  [0.9975344  0.00246556]
#  [0.99755716 0.00244285]
#  [0.9971631  0.00283685]
#  [0.997493   0.00250694]
#  [0.99766517 0.0023349 ]
#  [0.9975389  0.00246105]
#  [0.9974999  0.00250009]
#  [0.99754995 0.00245003]
#  [0.9977639  0.00223612]
#  [0.99743986 0.00256008]
#  [0.99764794 0.00235206]
#  [0.9975406  0.00245944]
#  [0.9975545  0.00244549]
#  [0.9976031  0.00239696]
#  [0.99729    0.00271   ]
#  [0.99759656 0.0024034 ]
#  [0.9974203  0.00257964]
#  [0.99735606 0.00264395]
#  [0.99738663 0.00261341]
#  [0.9973617  0.00263832]
#  [0.9974354  0.00256459]
#  [0.9974031  0.00259687]
#  [0.99743026 0.00256975]
#  [0.99746656 0.00253338]
#  [0.99737203 0.00262799]
#  [0.99751115 0.00248886]
#  [0.9976355  0.00236446]
#  [0.99728596 0.00271402]
#  [0.9971963  0.00280371]]
# I0815 04:49:54.968533 140310752536448 basic_session_run_hooks.py:262] loss = 3.1508338, step = 1
# I0815 04:49:54.970676 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 2 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 04:49:55.815032 140310752536448 estimator.py:368] Loss for final step: 3.1508338.

# %% [markdown]
# #### Now—without logging each step—set steps=1000 to train the model longer, but in a reasonable time to run this example. Training CNNs is computationally intensive. To increase the accuracy of your model, increase the number of steps passed to train(), like 20,000 steps.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0815 04:50:11.507346 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 04:50:11.691701 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 04:50:11.694583 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# input layer shape:  Tensor("Shape:0", shape=(4,), dtype=int32)
# (500, 150, 150, 3)
# con1 shape:  Tensor("Shape_1:0", shape=(4,), dtype=int32)
# (500, 150, 150, 32)
# pool1 Layer shape:  Tensor("Shape_2:0", shape=(4,), dtype=int32)
# (500, 75, 75, 32)
# local_response_normalization shape:  Tensor("Shape_3:0", shape=(4,), dtype=int32)
# (500, 75, 75, 32)
# con2 Layer shape:  Tensor("Shape_4:0", shape=(4,), dtype=int32)
# (500, 75, 75, 64)
# pool2 Layer shape:  Tensor("Shape_5:0", shape=(4,), dtype=int32)
# (500, 37, 37, 64)
# pool2_flat shape:  Tensor("Shape_6:0", shape=(2,), dtype=int32)
# (500, 87616)
# dense Layer shape:  Tensor("Shape_7:0", shape=(2,), dtype=int32)
# (500, 1024)
# logits Layer shape:  Tensor("Shape_8:0", shape=(2,), dtype=int32)
# (500, 2)
# Train Loss:
# Mode:  train
# I0815 04:50:11.776494 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 04:50:11.782538 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-2
# I0815 04:50:12.022467 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 04:50:12.027201 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 04:50:12.198790 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 2 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 04:50:13.787327 140310752536448 basic_session_run_hooks.py:262] loss = 8.74713, step = 2
# I0815 04:51:27.124103 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.36356
# I0815 04:51:27.126646 140310752536448 basic_session_run_hooks.py:260] loss = 0.70108175, step = 102 (73.339 sec)
# I0815 04:52:39.440700 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38281
# I0815 04:52:39.444648 140310752536448 basic_session_run_hooks.py:260] loss = 0.54832506, step = 202 (72.318 sec)
# I0815 04:53:52.351931 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37153
# I0815 04:53:52.354620 140310752536448 basic_session_run_hooks.py:260] loss = 0.4619966, step = 302 (72.910 sec)
# I0815 04:55:05.154835 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37357
# I0815 04:55:05.157463 140310752536448 basic_session_run_hooks.py:260] loss = 0.28253174, step = 402 (72.803 sec)
# I0815 04:56:17.133440 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.3893
# I0815 04:56:17.136301 140310752536448 basic_session_run_hooks.py:260] loss = 0.29813206, step = 502 (71.979 sec)
# I0815 04:57:29.620110 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37956
# I0815 04:57:29.622409 140310752536448 basic_session_run_hooks.py:260] loss = 0.26576653, step = 602 (72.486 sec)
# I0815 04:58:41.587187 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38952
# I0815 04:58:41.589831 140310752536448 basic_session_run_hooks.py:260] loss = 0.18863474, step = 702 (71.967 sec)
# I0815 04:59:53.882363 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38322
# I0815 04:59:53.885255 140310752536448 basic_session_run_hooks.py:260] loss = 0.2529884, step = 802 (72.295 sec)
# I0815 05:00:13.398411 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 830 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:01:07.060742 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.36652
# I0815 05:01:07.062736 140310752536448 basic_session_run_hooks.py:260] loss = 0.23739395, step = 902 (73.177 sec)
# I0815 05:02:18.784322 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1002 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:02:19.607138 140310752536448 estimator.py:368] Loss for final step: 0.23581077.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=20,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0815 05:02:19.670747 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 05:02:19.798790 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 05:02:19.821457 140310752536448 evaluation.py:255] Starting evaluation at 2019-08-15T05:02:19Z
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# input layer shape:  Tensor("Shape:0", shape=(4,), dtype=int32)
# (?, 150, 150, 3)
# con1 shape:  Tensor("Shape_1:0", shape=(4,), dtype=int32)
# (?, 150, 150, 32)
# pool1 Layer shape:  Tensor("Shape_2:0", shape=(4,), dtype=int32)
# (?, 75, 75, 32)
# local_response_normalization shape:  Tensor("Shape_3:0", shape=(4,), dtype=int32)
# (?, 75, 75, 32)
# con2 Layer shape:  Tensor("Shape_4:0", shape=(4,), dtype=int32)
# (?, 75, 75, 64)
# pool2 Layer shape:  Tensor("Shape_5:0", shape=(4,), dtype=int32)
# (?, 37, 37, 64)
# pool2_flat shape:  Tensor("Shape_6:0", shape=(2,), dtype=int32)
# (?, 87616)
# dense Layer shape:  Tensor("Shape_7:0", shape=(2,), dtype=int32)
# (?, 1024)
# logits Layer shape:  Tensor("Shape_8:0", shape=(2,), dtype=int32)
# (?, 2)
# Train Loss:
# I0815 05:02:19.906940 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 05:02:19.912649 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-1002
# I0815 05:02:20.155946 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 05:02:20.167828 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 05:02:31.084323 140310752536448 evaluation.py:275] Finished evaluation at 2019-08-15-05:02:31
# I0815 05:02:31.085699 140310752536448 estimator.py:2039] Saving dict for global step 1002: accuracy = 0.8682766, global_step = 1002, loss = 0.29873076
# I0815 05:02:31.126257 140310752536448 estimator.py:2099] Saving 'checkpoint_path' summary for global step 1002: Estimator//actfn_convnet_model/model.ckpt-1002
# {'accuracy': 0.8682766, 'loss': 0.29873076, 'global_step': 1002}

# %%
eval_metric_ops={'my_accuracy': eval_results}
print(eval_metric_ops)
# tf.summary.scalar('accuracy', eval_results[1])
# Out:
# {'my_accuracy': {'accuracy': 0.8682766, 'loss': 0.29873076, 'global_step': 1002}}

# %% [markdown]
# - From our sigmoid function we are achieving 'accuracy': 0.9143798 'loss': 0.23210417

# %% [markdown]
# ## <span style="color:#b80f0f"> tanH function

# %% [markdown]
# <img src="Presentation/tanH.png" width="400" height="200" align="center" >

# %% [markdown]
# `Zero centered`- making it easier to model inputs that
# have strongly negative, neutral, and strongly positive values.
# Otherwise like the Sigmoid function.

# %%
act_func_global=tf.nn.tanh
estimator_path='tanh'
print(act_func_global)
is_Swish = False
is_SwishBeta = False
is_First = False
# Out:
# <function tanh at 0x7f9c5ef64048>

# %% [markdown]
# ### Train the model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=None,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# W0814 15:52:47.312209 12164 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0814 15:52:47.331158 12164 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0814 15:52:47.333152 12164 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# I0814 15:52:47.348112 12164 estimator.py:1145] Calling model_fn.
# W0814 15:52:47.353099 12164 deprecation.py:323] From <ipython-input-14-e37c3dcb5a46>:24: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0814 15:52:47.356091 12164 deprecation.py:506] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# act_func_global:  <function tanh at 0x0000029F314AA5E8>
# W0814 15:52:47.577499 12164 deprecation.py:323] From <ipython-input-14-e37c3dcb5a46>:30: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# W0814 15:52:47.708149 12164 deprecation.py:323] From <ipython-input-14-e37c3dcb5a46>:75: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0814 15:52:48.003790 12164 deprecation.py:323] From C:\Users\kaila\Anaconda3\envs\tensorflow_gpuenv\lib\site-packages\tensorflow\python\ops\losses\losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# I0814 15:52:48.094117 12164 estimator.py:1147] Done calling model_fn.
# I0814 15:52:48.095118 12164 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# Train Loss:
# Mode:  train
# I0814 15:52:48.422081 12164 monitored_session.py:240] Graph was finalized.

# %% [markdown]
# #### Now—without logging each step—set steps=1000 to train the model longer, but in a reasonable time to run this example. Training CNNs is computationally intensive. To increase the accuracy of your model, increase the number of steps passed to train(), like 20,000 steps.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0815 05:03:48.360316 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 05:03:48.517501 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 05:03:48.520214 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function tanh at 0x7f9c5ef64048>
# Train Loss:
# Mode:  train
# I0815 05:03:48.598690 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 05:03:48.604630 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-1002
# I0815 05:03:48.845002 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 05:03:48.849663 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 05:03:49.001688 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1002 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:03:50.701527 140310752536448 basic_session_run_hooks.py:262] loss = 2.2797182, step = 1002
# I0815 05:05:04.036274 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.3636
# I0815 05:05:04.039071 140310752536448 basic_session_run_hooks.py:260] loss = 1.7322787, step = 1102 (73.338 sec)
# I0815 05:06:17.058977 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.36944
# I0815 05:06:17.061124 140310752536448 basic_session_run_hooks.py:260] loss = 0.358382, step = 1202 (73.022 sec)
# I0815 05:07:29.747347 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37574
# I0815 05:07:29.750439 140310752536448 basic_session_run_hooks.py:260] loss = 0.14588435, step = 1302 (72.689 sec)
# I0815 05:08:42.024301 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38357
# I0815 05:08:42.027100 140310752536448 basic_session_run_hooks.py:260] loss = 0.22965042, step = 1402 (72.277 sec)
# I0815 05:09:54.977663 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37074
# I0815 05:09:54.980268 140310752536448 basic_session_run_hooks.py:260] loss = 0.1264346, step = 1502 (72.953 sec)
# I0815 05:11:07.835635 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37253
# I0815 05:11:07.838290 140310752536448 basic_session_run_hooks.py:260] loss = 0.09897358, step = 1602 (72.858 sec)
# I0815 05:12:20.469957 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37676
# I0815 05:12:20.472384 140310752536448 basic_session_run_hooks.py:260] loss = 0.08764905, step = 1702 (72.634 sec)
# I0815 05:13:33.159935 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.3757
# I0815 05:13:33.162114 140310752536448 basic_session_run_hooks.py:260] loss = 0.07155545, step = 1802 (72.690 sec)
# I0815 05:13:49.896934 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1826 into Estimator//actfn_convnet_model/model.ckpt.
# W0815 05:13:50.567585 140310752536448 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# I0815 05:14:46.469902 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.36407
# I0815 05:14:46.472794 140310752536448 basic_session_run_hooks.py:260] loss = 0.19793664, step = 1902 (73.311 sec)
# I0815 05:15:58.416664 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 2002 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:15:59.077415 140310752536448 estimator.py:368] Loss for final step: 0.08617581.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=20,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0815 05:15:59.112116 140310752536448 estimator.py:1145] Calling model_fn.
# act_func_global:  <function tanh at 0x7f9c5ef64048>
# Train Loss:
# I0815 05:15:59.463924 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 05:15:59.486999 140310752536448 evaluation.py:255] Starting evaluation at 2019-08-15T05:15:59Z
# I0815 05:15:59.580812 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 05:15:59.586936 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-2002
# I0815 05:15:59.823752 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 05:15:59.837065 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 05:16:09.657248 140310752536448 evaluation.py:275] Finished evaluation at 2019-08-15-05:16:09
# I0815 05:16:09.658469 140310752536448 estimator.py:2039] Saving dict for global step 2002: accuracy = 0.92755216, global_step = 2002, loss = 0.17716856
# I0815 05:16:09.659833 140310752536448 estimator.py:2099] Saving 'checkpoint_path' summary for global step 2002: Estimator//actfn_convnet_model/model.ckpt-2002
# {'accuracy': 0.92755216, 'loss': 0.17716856, 'global_step': 2002}

# %% [markdown]
# ## <span style="color:#b80f0f"> ReLU (Rectified Linear Unit)

# %% [markdown]
# <img src="Presentation/ReLU.png" width="500" height="200" align="center" >

# %% [markdown]
# `Computationally efficient`—allows the network to converge very quickly <br />
# `Non-linear`—although it looks like a linear function, ReLU has a derivative function and allows for backpropagation
# ![image.png](attachment:image.png)

# %%
act_func_global=tf.nn.relu
estimator_path='relu'

print(act_func_global)
is_Swish = False
is_SwishBeta = False
is_First = False
# Out:
# <function relu at 0x7f9c5ecc9400>

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=None,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# I0815 05:16:09.708414 140310752536448 estimator.py:1145] Calling model_fn.
# act_func_global:  <function relu at 0x7f9c5ecc9400>
# Train Loss:
# Mode:  train
# I0815 05:16:09.873735 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 05:16:09.875784 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0815 05:16:09.949218 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 05:16:09.954469 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-2002
# I0815 05:16:10.258585 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 05:16:10.264417 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 05:16:10.427521 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 2002 into Estimator//actfn_convnet_model/model.ckpt.
# I0815
#  [0.9911841  0.00881597]
#  [0.1379354  0.86206466]
#  [0.99979013 0.00020989]
#  [0.54494894 0.45505103]
#  [0.731      0.26900005]
#  [0.75131047 0.2486896 ]
#  [0.9650602  0.03493988]
#  [0.93526375 0.0647362 ]
#  [0.9993662  0.00063383]
#  [0.9749868  0.02501325]
#  [0.43728358 0.5627164 ]
#  [0.99950516 0.00049482]
#  [0.85290647 0.14709352]
#  [0.9983322  0.00166784]
#  [0.60421085 0.39578915]
#  [0.86816484 0.13183522]
#  [0.7586181  0.2413819 ]
#  [0.8577986  0.1422014 ]
#  [0.72393197 0.276068  ]
#  [0.9870946  0.0129054 ]
#  [0.88113695 0.11886305]
#  [0.9544086  0.04559144]
#  [0.99856925 0.00143077]
#  [0.9826909  0.01730907]
#  [0.8388907  0.16110936]
#  [0.98064005 0.01935995]
#  [0.9999225  0.00007746]
#  [0.04455405 0.95544595]
#  [0.5548701  0.44512987]
#  [0.9789367  0.02106331]
#  [0.7757973  0.22420268]
#  [0.997931   0.00206898]
#  [0.9826628  0.01733726]
#  [0.8924653  0.10753465]]
# I0815 05:16:12.173379 140310752536448 basic_session_run_hooks.py:262] loss = 2.286265, step = 2002
# I0815 05:16:12.176337 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 2003 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:16:13.053126 140310752536448 estimator.py:368] Loss for final step: 2.286265.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0815 05:16:13.095040 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 05:16:13.283745 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 05:16:13.286550 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function relu at 0x7f9c5ecc9400>
# Train Loss:
# Mode:  train
# I0815 05:16:13.375882 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 05:16:13.383096 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-2003
# I0815 05:16:13.693763 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 05:16:13.700684 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 05:16:13.921494 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 2003 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:16:15.395878 140310752536448 basic_session_run_hooks.py:262] loss = 17.60647, step = 2003
# I0815 05:17:27.422018 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38837
# I0815 05:17:27.424401 140310752536448 basic_session_run_hooks.py:260] loss = 0.37363455, step = 2103 (72.029 sec)
# I0815 05:18:39.374544 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38981
# I0815 05:18:39.377404 140310752536448 basic_session_run_hooks.py:260] loss = 0.28458783, step = 2203 (71.953 sec)
# I0815 05:19:51.766644 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38136
# I0815 05:19:51.771434 140310752536448 basic_session_run_hooks.py:260] loss = 0.15783922, step = 2303 (72.394 sec)
# I0815 05:21:04.234281 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37993
# I0815 05:21:04.236280 140310752536448 basic_session_run_hooks.py:260] loss = 0.1969086, step = 2403 (72.465 sec)
# I0815 05:22:16.419034 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38533
# I0815 05:22:16.421705 140310752536448 basic_session_run_hooks.py:260] loss = 0.37727943, step = 2503 (72.185 sec)
# I0815 05:23:28.240449 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.39234
# I0815 05:23:28.242992 140310752536448 basic_session_run_hooks.py:260] loss = 0.098554604, step = 2603 (71.821 sec)
# I0815 05:24:40.400950 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.3858
# I0815 05:24:40.405702 140310752536448 basic_session_run_hooks.py:260] loss = 0.08499389, step = 2703 (72.163 sec)
# I0815 05:25:53.269188 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37234
# I0815 05:25:53.271892 140310752536448 basic_session_run_hooks.py:260] loss = 1.1349937, step = 2803 (72.866 sec)
# I0815 05:26:15.140269 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 2834 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:27:06.252370 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37018
# I0815 05:27:06.255031 140310752536448 basic_session_run_hooks.py:260] loss = 0.33600348, step = 2903 (72.983 sec)
# I0815 05:28:18.042038 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 3003 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:28:18.643150 140310752536448 estimator.py:368] Loss for final step: 0.06054637.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=100,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0815 05:48:37.440521 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 05:48:37.546947 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 05:48:37.567244 140310752536448 evaluation.py:255] Starting evaluation at 2019-08-15T05:48:37Z
# act_func_global:  <function relu at 0x7f9c5ecc9400>
# Train Loss:
# I0815 05:48:37.648769 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 05:48:37.654350 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-3003
# I0815 05:48:37.897642 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 05:48:37.908282 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 05:49:26.786292 140310752536448 evaluation.py:275] Finished evaluation at 2019-08-15-05:49:26
# I0815 05:49:26.787230 140310752536448 estimator.py:2039] Saving dict for global step 3003: accuracy = 0.935236, global_step = 3003, loss = 0.1615891
# I0815 05:49:26.788300 140310752536448 estimator.py:2099] Saving 'checkpoint_path' summary for global step 3003: Estimator//actfn_convnet_model/model.ckpt-3003
# {'accuracy': 0.935236, 'loss': 0.1615891, 'global_step': 3003}

# %% [markdown]
# ## <span style="color:#b80f0f"> Leaky ReLU

# %% [markdown]
# <img src="Presentation/leaky_ReLU.png" width="500" height="200" align="center" >

# %% [markdown]
# `Prevents dying ReLU problem`- this variation of ReLU has a small positive slope in the negative area, so it does enable `backpropagation`, even for negative input values.
# Otherwise Like a ReLU![image.png](attachment:image.png)

# %%
act_func_global=tf.nn.leaky_relu
estimator_path='leaky_relu'

print(act_func_global)
is_Swish = False
is_SwishBeta = False
is_First = False
# Out:
# <function leaky_relu at 0x7f9c5dfc4840>

# %% [markdown]
# ### Train the model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=200,
    num_epochs=50,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# I0815 05:56:46.596257 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 05:56:46.768834 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 05:56:46.771585 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function leaky_relu at 0x7f9c5dfc4840>
# Train Loss:
# Mode:  train
# I0815 05:56:46.852482 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 05:56:46.913067 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 05:56:46.918437 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 05:56:47.073677 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for
#  [0.01272919 0.98727083]
#  [0.01381153 0.9861885 ]
#  [0.02878028 0.97121966]
#  [0.01430543 0.9856946 ]
#  [0.20831412 0.7916859 ]
#  [0.0083315  0.99166846]
#  [0.01134887 0.98865116]
#  [0.00140086 0.9985991 ]
#  [0.03892961 0.9610704 ]
#  [0.01563998 0.98436004]
#  [0.00167536 0.9983246 ]
#  [0.00490927 0.9950907 ]
#  [0.01440494 0.9855951 ]
#  [0.02146331 0.9785367 ]
#  [0.00051237 0.99948764]
#  [0.01511077 0.98488927]]
# I0815 05:56:48.954793 140310752536448 basic_session_run_hooks.py:262] loss = 1.8827738, step = 0
# I0815 05:56:48.958151 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:56:49.584442 140310752536448 estimator.py:368] Loss for final step: 1.8827738.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=100)
# Out:
# I0815 05:57:08.297285 140310752536448 estimator.py:1145] Calling model_fn.
# act_func_global:  <function leaky_relu at 0x7f9c5dfc4840>
# Train Loss:
# Mode:  train
# I0815 05:57:08.619403 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 05:57:08.622296 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# I0815 05:57:08.693628 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 05:57:08.699812 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-1
# I0815 05:57:08.938928 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 05:57:08.947031 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 05:57:09.124573 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 05:57:09.879385 140310752536448 basic_session_run_hooks.py:262] loss = 468.0126, step = 1
# E0815 05:57:11.280504 140310752536448 basic_session_run_hooks.py:760] Model diverged with loss = NaN.
# ---------------------------------------------------------------------------
# NanLossDuringTrainingError                Traceback (most recent call last)
# <ipython-input-85-092be4507d3b> in <module>()
# ----> 1 actfn_classifier.train(input_fn=train_input_fn, steps=100)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     365
#     366       saving_listeners = _check_listeners_type(saving_listeners)
# --> 367       loss = self._train_model(input_fn, hooks, saving_listeners)
#     368       logging.info('Loss for final step: %s.', loss)
#     369       return self
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1157     else:
# -> 1158       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1159
#    1160   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1190       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1191                                              hooks, global_step_tensor,
# -> 1192                                              saving_listeners)
#    1193
#    1194   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1482       any_step_done = False
#    1483       while not mon_sess.should_stop():
# -> 1484         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1485         any_step_done = True
#    1486     if not any_step_done:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     752         feed_dict=feed_dict,
#     753         options=options,
# --> 754         run_metadata=run_metadata)
#     755
#     756   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1250             feed_dict=feed_dict,
#    1251             options=options,
# -> 1252             run_metadata=run_metadata)
#    1253       except _PREEMPTION_ERRORS as e:
#    1254         logging.info(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1351         raise six.reraise(*original_exc_info)
#    1352       else:
# -> 1353         raise six.reraise(*original_exc_info)
#    1354
#    1355
#
# /usr/local/lib/python3.6/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1336   def run(self, *args, **kwargs):
#    1337     try:
# -> 1338       return self._sess.run(*args, **kwargs)
#    1339     except _PREEMPTION_ERRORS:
#    1340       raise
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1417               results=outputs[hook] if hook in outputs else None,
#    1418               options=options,
# -> 1419               run_metadata=run_metadata))
#    1420     self._should_stop = self._should_stop or run_context.stop_requested
#    1421
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/basic_session_run_hooks.py in after_run(self, run_context, run_values)
#     759       if self._fail_on_nan_loss:
#     760         logging.error(failure_message)
# --> 761         raise NanLossDuringTrainingError
#     762       else:
#     763         logging.warning(failure_message)
#
# NanLossDuringTrainingError: NaN loss during training.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=None,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)

# %% [markdown]
# ## <span style="color:#b80f0f"> Swish

# %% [markdown]
# <img src="Presentation/swish.png" width="500" height="200" align="center" >

# %% [markdown]
# `Swish` is a new, self-gated activation function discovered by researchers at Google.<br />
# Swish mathematical expression: `f(x) = x * σ(x)` <br />
# where `σ(x)= sigmoid function`

# %% [markdown]
# #### Set a activation function

# %%
act_func_global=tf.nn.sigmoid
estimator_path='swish'

print(act_func_global)
is_Swish = True
is_SwishBeta = False
is_First = False

def swish_1(x):
    act_func_global = x*tf.nn.sigmoid(x)
    return act_func_global
# Out:
# <function sigmoid at 0x7f9c5ec00f28>

# %% [markdown]
# ### Train the model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=None,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# I0815 06:30:10.656176 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 06:30:10.829933 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 06:30:10.832393 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# Train Loss:
# Mode:  train
# I0815 06:30:10.916438 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 06:30:10.976125 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 06:30:10.985066 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 06:30:11.161663 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 0 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 06:30:12.848520 140310752536448 basic_session_run_hooks.py:262] probabilities = [[0.4093044  0.5906956 ]
#  [0.40309852 0.5969014 ]
#  [0.3927775  0.6072225 ]
#  [0.38524762 0.6147524 ]
#  [0.40443504 0.595565  ]
#  [0.40994543 0.5900546 ]
#  [0.39757827 0.6024217 ]
#  [0.4035098  0.59649026]
#  [0.39449698 0.60550296]
#  [0.39915556 0.60084444]
#  [0.402163   0.597837  ]
#  [0.37964916 0.6203509 ]
#  [0.403762   0.59623796]
#  [0.40029776 0.5997022 ]
#  [0.39587304 0.60412693]
#  [0.40252185 0.59747815]
#  [0.39519233 0.6048076 ]
#  [0.39448115 0.6055188 ]
#  [0.39473277 0.6052672 ]
#  [0.39935434 0.60064566]
#  [0.39147544 0.60852456]
#  [0.40295228 0.59704775]
#  [0.40942624 0.5905738 ]
#  [0.41037768 0.5896224 ]
#  [0.41063547 0.5893645 ]
#  [0.40211374 0.59788626]
#  [0.40020204 0.59979796]
#  [0.40403944 0.5959605 ]
#  [0.3953639  0.60463613]
#  [0.40136242 0.5986376 ]
#  [0.39720294 0.60279703]
#  [0.40376225 0.5962377 ]
#  [0.40499675 0.59500325]
#  [0.40229717 0.59770286]
#  [0.41086304 0.58913696]
#  [0.39301145 0.6069885 ]
#  [0.39385355 0.60614645]
#  [0.39392233 0.6060777 ]
#  [0.40258017 0.5974198 ]
#  [0.3947879  0.6052121 ]
#  [0.39347222 0.6065278 ]
#  [0.4072676  0.5927324 ]
#  [0.4002065  0.59979343]
#  [0.3949174  0.6050826 ]
#  [0.4075369  0.5924631 ]
#  [0.39492613 0.6050739 ]
#  [0.40764627 0.59235376]
#  [0.39480552 0.6051945 ]
#  [0.39817342 0.6018266 ]
#  [0.40534478 0.59465516]
#  [0.40087855 0.59912145]
#  [0.39143124 0.6085688 ]
#  [0.39804283 0.6019572 ]
#  [0.40237424 0.59762573]
#  [0.40533635 0.5946637 ]
#  [0.3921038  0.6078962 ]
#  [0.39929196 0.60070807]]
# I0815 06:30:12.850334 140310752536448 basic_session_run_hooks.py:262] loss = 0.7066068, step = 0
# I0815 06:30:12.851734 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 06:30:13.730188 140310752536448 estimator.py:368] Loss for final step: 0.7066068.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0815 06:30:30.287204 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 06:30:30.463720 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 06:30:30.467174 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# Train Loss:
# Mode:  train
# I0815 06:30:30.551507 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 06:30:30.558066 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-1
# I0815 06:30:30.852229 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 06:30:30.857402 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 06:30:31.028148 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 06:30:32.402859 140310752536448 basic_session_run_hooks.py:262] loss = 1.5415294, step = 1
# I0815 06:31:45.301578 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37176
# I0815 06:31:45.304165 140310752536448 basic_session_run_hooks.py:260] loss = 0.6219105, step = 101 (72.901 sec)
# I0815 06:32:57.415360 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.3867
# I0815 06:32:57.418081 140310752536448 basic_session_run_hooks.py:260] loss = 0.69371486, step = 201 (72.114 sec)
# I0815 06:34:10.202597 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37387
# I0815 06:34:10.205483 140310752536448 basic_session_run_hooks.py:260] loss = 0.29760095, step = 301 (72.787 sec)
# I0815 06:35:22.920543 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37518
# I0815 06:35:22.923306 140310752536448 basic_session_run_hooks.py:260] loss = 0.33529595, step = 401 (72.718 sec)
# I0815 06:36:35.937272 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.36955
# I0815 06:36:35.941073 140310752536448 basic_session_run_hooks.py:260] loss = 0.28292075, step = 501 (73.018 sec)
# I0815 06:37:48.274771 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38241
# I0815 06:37:48.277588 140310752536448 basic_session_run_hooks.py:260] loss = 0.26081738, step = 601 (72.337 sec)
# I0815 06:39:00.632632 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38202
# I0815 06:39:00.634766 140310752536448 basic_session_run_hooks.py:260] loss = 0.26342317, step = 701 (72.357 sec)
# I0815 06:40:13.307881 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37598
# I0815 06:40:13.310498 140310752536448 basic_session_run_hooks.py:260] loss = 0.17952922, step = 801 (72.676 sec)
# I0815 06:40:32.225484 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 828 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 06:41:27.351567 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.35055
# I0815 06:41:27.354587 140310752536448 basic_session_run_hooks.py:260] loss = 0.28108084, step = 901 (74.044 sec)
# I0815 06:42:39.465268 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1001 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 06:42:40.356541 140310752536448 estimator.py:368] Loss for final step: 0.2698108.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=100,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0815 06:42:40.393402 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 06:42:40.513630 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 06:42:40.535128 140310752536448 evaluation.py:255] Starting evaluation at 2019-08-15T06:42:40Z
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# Train Loss:
# I0815 06:42:40.622998 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 06:42:40.627721 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-1001
# I0815 06:42:40.934019 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 06:42:40.945228 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 06:43:29.894927 140310752536448 evaluation.py:275] Finished evaluation at 2019-08-15-06:43:29
# I0815 06:43:29.896179 140310752536448 estimator.py:2039] Saving dict for global step 1001: accuracy = 0.92755216, global_step = 1001, loss = 0.21094483
# I0815 06:43:29.897325 140310752536448 estimator.py:2099] Saving 'checkpoint_path' summary for global step 1001: Estimator//actfn_convnet_model/model.ckpt-1001
# {'accuracy': 0.92755216, 'loss': 0.21094483, 'global_step': 1001}

# %% [markdown]
# ## <span style="color:#b80f0f"> Swish-Beta

# %% [markdown]
# <img src="Presentation/swish_1.png" width="500" height="200" align="center" >

# %% [markdown]
# #### Set a activation function

# %%
act_func_global=tf.nn.sigmoid
estimator_path='swish_beta'

print(act_func_global)
is_Swish = False
is_SwishBeta = True
is_First = False

def swish_beta(x):
    beta=tf.Variable(initial_value=1.0,trainable=True,name='swish_beta')
    print('beta: ',beta)
    act_func_global = x*tf.nn.sigmoid(beta*x) #trainable parameter beta
    print('act_func_global: ',act_func_global)
    return act_func_global
# Out:
# <function sigmoid at 0x7f9c5ec00f28>

# %% [markdown]
# ### Train the model

# %%
# Train the model
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": train_data},
    y=train_labels,
    batch_size=b_size,
    num_epochs=None,
    shuffle=True)

# train one step and display the probabilties
actfn_classifier.train(
    input_fn=train_input_fn,
    steps=1,
    hooks=[logging_hook])
# Out:
# I0815 06:50:04.740410 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 06:50:04.934999 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 06:50:04.937717 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# beta:  <tf.Variable 'swish_beta:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_1:0", shape=(500, 150, 150, 3), dtype=float32)
# beta:  <tf.Variable 'swish_beta_1:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_3:0", shape=(500, 75, 75, 32), dtype=float32)
# beta:  <tf.Variable 'swish_beta_2:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_5:0", shape=(500, 87616), dtype=float32)
# Train Loss:
# Mode:  train
# I0815 06:50:05.020400 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 06:50:05.079077 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 06:50:05.084050 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 06:50:05.249155 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 0 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 06:50:06.866287 140310752536448 basic_session_run_hooks.py:262] probabilities = [[0.54039377 0.45960623]
#  [0.534562   0.46543795]
#  [0.538334   0.46166602]
#  [0.54732984 0.45267013]
#  [0.52618515 0.47381482]
#  [0.5259615  0.47403845]
#  [0.53610456 0.46389544]
#  [0.5501698  0.44983014]
#  [0.53678966 0.46321034]
#  [0.5478505  0.45214954]
#  [0.5438734  0.45612654]
#  [0.5485378  0.4514622 ]
#  [0.5423629  0.45763707]
#  [0.5324482  0.4675518 ]
#  [0.5348955  0.46510452]
#  [0.5425229  0.4574771 ]
#  [0.5471485  0.45285144]
#  [0.5342011  0.46579885]
#  [0.53996    0.46004003]
#  [0.5439543  0.45604572]
#  [0.5274519  0.47254816]
#  [0.5418296  0.4581704 ]
#  [0.5429477  0.45705232]
#  [0.5389716  0.46102837]
#  [0.53780097 0.462199  ]
#  [0.539383   0.46061704]
#  [0.54149884 0.45850113]
#  [0.5318048  0.46819517]
#  [0.53763574 0.46236426]
#  [0.5380344  0.46196565]
#  [0.5357221  0.46427798]
#  [0.53852254 0.4614774 ]
#  [0.54992205 0.45007795]
#  [0.542457   0.45754302]
#  [0.5407495  0.4592505 ]
#  [0.54551077 0.4544892 ]
#  [0.5442269  0.45577312]
#  [0.5424204  0.4575796 ]
#  [0.52122957 0.4787704 ]
#  [0.55058694 0.44941312]
#  [0.5474545  0.4525455 ]
#  [0.5469841  0.45301592]
#  [0.5306381  0.4693619 ]
#  [0.5335002  0.4664998 ]
#  [0.5372209  0.46277907]
#  [0.5463066  0.45369342]
#  [0.53818405 0.46181592]
#  [0.5349722  0.46502778]
#  [0.5434656  0.45653436]
#  [0.54028773 0.45971227]
#  [0.5483729  0.45162708]
#  [0.5379469  0.46205312]
#  [0.5366369  0.46336314]
#  [0.540176   0.459824  ]
#  [0.5325137  0.4674863 ]
#  [0.5388799  0.46112016]
#  [0.5382916  0.46170846]
#  [0.5321205  0.4678794 ]
#  [0.52892697 0.4710731 ]
#  [0.5399634  0.46003664]
#  [0.54168606 0.45831394]
#  [0.5449044  0.4550956 ]
#  [0.53961813 0.4603819 ]
#  [0.5374216  0.46257845]
#  [0.5381701  0.46182993]
#  [0.54290414 0.45709592]
#  [0.5306959  0.46930408]
#  [0.5291182  0.47088185]
#  [0.5364512  0.46354878]
#  [0.5370666  0.46293342]
#  [0.5386267  0.4613734 ]
#  [0.54565614 0.45434386]
#  [0.5302932  0.4697068 ]
#  [0.5392144  0.4607856 ]
#  [0.5447225  0.4552775 ]
#  [0.54768384 0.45231616]
#  [0.53833216 0.46166784]
#  [0.5450111  0.45498887]
#  [0.53328186 0.46671814]
#  [0.54230446 0.45769557]
#  [0.5513827  0.44861728]
#  [0.53824    0.46176   ]
#  [0.5415006  0.45849934]
#  [0.54947734 0.45052263]
#  [0.5384008  0.4615992 ]
#  [0.5337693  0.4662307 ]
#  [0.53521734 0.46478269]
#  [0.5318132  0.46818674]
#  [0.5413907  0.45860925]
#  [0.53890014 0.46109983]
#  [0.5297502  0.47024977]
#  [0.5187964  0.48120362]
#  [0.5364909  0.46350908]
#  [0.54482144 0.4551786 ]
#  [0.5173476  0.4826524 ]
#  [0.5393089  0.46069106]
#  [0.5356122  0.46438774]
#  [0.5421392  0.45786083]
#  [0.54957104 0.45042896]
#  [0.539832   0.46016803]
#  [0.53725153 0.4627485 ]
#  [0.5338329  0.46616703]
#  [0.5350887  0.46491128]
#  [0.5338285  0.4661715 ]
#  [0.53629875 0.46370128]
#  [0.5402683  0.4597317 ]
#  [0.5398382  0.46016183]
#  [0.5531965  0.4468035 ]
#  [0.54227835 0.45772162]
#  [0.5284107  0.4715893 ]
#  [0.54484606 0.45515394]
#  [0.5388942  0.46110585]
#  [0.540715   0.45928505]
#  [0.53199816 0.46800184]
#  [0.52962124 0.47037876]
#  [0.544107   0.45589298]
#  [0.5565623  0.44343776]
#  [0.5385786  0.4614214 ]
#  [0.5357814  0.46421865]
#  [0.5428163  0.45718372]
#  [0.5445107  0.45548928]
#  [0.54199284 0.45800716]
#  [0.53189254 0.4681075 ]
#  [0.5321432  0.46785682]
#  [0.54580003 0.45419994]
#  [0.5364836  0.46351635]
#  [0.5424618  0.4575382 ]
#  [0.53377193 0.46622804]
#  [0.54661125 0.45338875]
#  [0.5436014  0.45639864]
#  [0.5423811  0.45761895]
#  [0.54574686 0.4542532 ]
#  [0.5324325  0.46756747]]
# I0815 06:50:06.868506 140310752536448 basic_session_run_hooks.py:262] loss = 0.7008543, step = 0
# I0815 06:50:06.870864 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 06:50:07.702848 140310752536448 estimator.py:368] Loss for final step: 0.7008543.

# %%
actfn_classifier.train(input_fn=train_input_fn, steps=1000)
# Out:
# I0815 06:50:15.826818 140310752536448 estimator.py:1145] Calling model_fn.
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# beta:  <tf.Variable 'swish_beta:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_1:0", shape=(500, 150, 150, 3), dtype=float32)
# I0815 06:50:16.250144 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 06:50:16.253054 140310752536448 basic_session_run_hooks.py:541] Create CheckpointSaverHook.
# beta:  <tf.Variable 'swish_beta_1:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_3:0", shape=(500, 75, 75, 32), dtype=float32)
# beta:  <tf.Variable 'swish_beta_2:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_5:0", shape=(500, 87616), dtype=float32)
# Train Loss:
# Mode:  train
# I0815 06:50:16.339320 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 06:50:16.345880 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-1
# I0815 06:50:16.659653 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 06:50:16.668234 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 06:50:16.897931 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 06:50:18.567821 140310752536448 basic_session_run_hooks.py:262] loss = 1.3054531, step = 1
# I0815 06:51:31.158924 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37757
# I0815 06:51:31.161375 140310752536448 basic_session_run_hooks.py:260] loss = 0.75521845, step = 101 (72.594 sec)
# I0815 06:52:43.631532 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37983
# I0815 06:52:43.634364 140310752536448 basic_session_run_hooks.py:260] loss = 0.6183227, step = 201 (72.473 sec)
# I0815 06:53:55.975276 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38229
# I0815 06:53:55.977787 140310752536448 basic_session_run_hooks.py:260] loss = 0.7610958, step = 301 (72.343 sec)
# I0815 06:55:08.373481 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38125
# I0815 06:55:08.376212 140310752536448 basic_session_run_hooks.py:260] loss = 0.36553082, step = 401 (72.398 sec)
# I0815 06:56:21.122694 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37458
# I0815 06:56:21.125296 140310752536448 basic_session_run_hooks.py:260] loss = 0.2727349, step = 501 (72.749 sec)
# I0815 06:57:33.502870 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.38159
# I0815 06:57:33.506867 140310752536448 basic_session_run_hooks.py:260] loss = 0.35754243, step = 601 (72.382 sec)
# I0815 06:58:46.134341 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37682
# I0815 06:58:46.138683 140310752536448 basic_session_run_hooks.py:260] loss = 0.34087697, step = 701 (72.632 sec)
# I0815 06:59:58.860781 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.37502
# I0815 06:59:58.864752 140310752536448 basic_session_run_hooks.py:260] loss = 0.17965806, step = 801 (72.726 sec)
# I0815 07:00:17.950048 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 828 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 07:01:13.282626 140310752536448 basic_session_run_hooks.py:692] global_step/sec: 1.34369
# I0815 07:01:13.285467 140310752536448 basic_session_run_hooks.py:260] loss = 0.24131024, step = 901 (74.421 sec)
# I0815 07:02:25.309879 140310752536448 basic_session_run_hooks.py:606] Saving checkpoints for 1001 into Estimator//actfn_convnet_model/model.ckpt.
# I0815 07:02:25.938048 140310752536448 estimator.py:368] Loss for final step: 0.19891064.

# %% [markdown]
# ### Evaluate the Model

# %%
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": eval_data},
    y=eval_labels,
    num_epochs=100,
    shuffle=False)

eval_results = actfn_classifier.evaluate(input_fn=eval_input_fn)
print(eval_results)
# Out:
# I0815 07:12:17.078444 140310752536448 estimator.py:1145] Calling model_fn.
# I0815 07:12:17.201066 140310752536448 estimator.py:1147] Done calling model_fn.
# I0815 07:12:17.223944 140310752536448 evaluation.py:255] Starting evaluation at 2019-08-15T07:12:17Z
# act_func_global:  <function sigmoid at 0x7f9c5ec00f28>
# beta:  <tf.Variable 'swish_beta:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_1:0", shape=(?, 150, 150, 3), dtype=float32)
# beta:  <tf.Variable 'swish_beta_1:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_3:0", shape=(?, 75, 75, 32), dtype=float32)
# beta:  <tf.Variable 'swish_beta_2:0' shape=() dtype=float32_ref>
# act_func_global:  Tensor("mul_5:0", shape=(?, 87616), dtype=float32)
# Train Loss:
# I0815 07:12:17.319062 140310752536448 monitored_session.py:240] Graph was finalized.
# I0815 07:12:17.325303 140310752536448 saver.py:1280] Restoring parameters from Estimator//actfn_convnet_model/model.ckpt-1001
# I0815 07:12:17.639406 140310752536448 session_manager.py:500] Running local_init_op.
# I0815 07:12:17.652907 140310752536448 session_manager.py:502] Done running local_init_op.
# I0815 07:13:06.425686 140310752536448 evaluation.py:275] Finished evaluation at 2019-08-15-07:13:06
# I0815 07:13:06.427034 140310752536448 estimator.py:2039] Saving dict for global step 1001: accuracy = 0.92425907, global_step = 1001, loss = 0.20035738
# I0815 07:13:06.428432 140310752536448 estimator.py:2099] Saving 'checkpoint_path' summary for global step 1001: Estimator//actfn_convnet_model/model.ckpt-1001
# {'accuracy': 0.92425907, 'loss': 0.20035738, 'global_step': 1001}
